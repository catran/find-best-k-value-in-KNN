# %%
#import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
input1 = pd.read_csv("input1.csv",encoding= 'ISO-8859-9',engine='python')
input1
# Out:
#       2020-08-11 11:00:00  28.7127685546875  40.9872436523438  sxk3jm   6  \
# 0     2020-08-09 19:00:00         29.371948         40.937805  sxkbuk  45
# 1     2020-08-25 10:00:00         28.888550         41.102600  sxk9c6   6
# 2     2020-08-06 20:00:00         29.075317         41.014709  sxk9md   6
# 3     2020-08-13 21:00:00         28.372192         41.163025  sxk4jt  58
# 4     2020-08-27 14:00:00         28.833618         40.965271  sxk901   7
# ...                   ...               ...               ...     ...  ..
# 9994  2020-08-05 01:00:00         29.426880         40.794983  sxkbjd  46
# 9995  2020-08-11 10:00:00         28.899536         41.102600  sxk9cd   6
# 9996  2020-08-11 20:00:00         28.602905         41.234436  sxk6df   7
# 9997  2020-08-04 15:00:00         28.690796         41.047668  sxk3sb   7
# 9998  2020-08-27 12:00:00         28.383179         41.053162  sxk1tc   7
#
#        78  32  252
# 0     186  99   47
# 1      73  27   87
# ...

# %%
link1 = pd.read_csv("afet-ibb_lokasyon.csv",encoding= 'ISO-8859-9',engine='python')
link2 = pd.read_csv("afet-mezarlk-adres-bilgileri.csv",encoding= 'ISO-8859-9',engine='python',sep=";")
link3 = pd.read_csv("afet-muhtarlk-adres-bilgileri.csv",encoding= 'ISO-8859-9',engine='python',sep=";")
link4 = pd.read_excel("cevre-2020-yl-lokasyon-baznda-cevresel-izleme-ve-kontrol-verileri-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='CO')
link5 = pd.read_excel("cevre-ilce-yl-ve-atk-turu-baznda-atk-miktar-20.xlsx",encoding= 'ISO-8859-9',sheet_name='Mekanik Süpürme Miktarı')
link6 = pd.read_excel("cevre-iski-ilce-bazl-car-says-ve-cozum-oran-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='İSKİ Çağrı Sayısı ve Çözüm Oran')
link7 = pd.read_excel("cevre-iski-ilce-ve-mahalle-bazl-gelen-ve-cevaplanan-kanal-arza-says-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='İlçe ve Mahalle B. Kanal Arıza ')
link8 = pd.read_excel("cevre-iski-ilce-ve-mahalle-bazl-gelen-ve-cevaplanan-su-arza-says-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='İlçe ve Mahalle B. Su Arıza S.')
link9 = pd.read_excel("cevre-iski-susuzluk-ikayet-ve-cevap-saylar-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='2019 Yılı İlçe Bazında Susuzluk')
link10 = pd.read_excel("cevre-istanbul-gune-enerji-santralleri-uretim-miktarlar.xlsx",encoding= 'ISO-8859-9',sheet_name='Ges Üretim Miktarları')
link11 = pd.read_excel("cevre-mavidepo3vdiuserprofilemeral.akardesktopsektor-ve-ilce-baznda-birinci-snf-gayrishhi-muessese-sa.xlsx",encoding= 'ISO-8859-9')
link12 = pd.read_csv("cevre-meteorology_observation_202001.csv",encoding= 'ISO-8859-9',engine='python')
link13 = pd.read_csv("cevre-meteorology_observation_202002.csv",encoding= 'ISO-8859-9',engine='python')
link14 = pd.read_csv("cevre-meteorology_observation_202003.csv",encoding= 'ISO-8859-9',engine='python')
link15 = pd.read_csv("cevre-meteorology_observation_202004.csv",encoding= 'ISO-8859-9',engine='python')
link16 = pd.read_csv("cevre-meteorology_observation_202005.csv",encoding= 'ISO-8859-9',engine='python')
link17 = pd.read_csv("cevre-meteorology_observation_202006.csv",encoding= 'ISO-8859-9',engine='python')
link18 = pd.read_csv("cevre-meteorology_observation_202007.csv",encoding= 'ISO-8859-9',engine='python')
link19 = pd.read_csv("cevre-meteorology_observation_202008.csv",encoding= 'ISO-8859-9',engine='python')
link20 = pd.read_csv("cevre-meteorology_observation_202009.csv",encoding= 'ISO-8859-9',engine='python')
link21 = pd.read_csv("cevre-meteorology_observation_202010.csv",encoding= 'ISO-8859-9',engine='python')
link22 = pd.read_csv("cevre-meteorology_observation_202011.csv",encoding= 'ISO-8859-9',engine='python')
link23 = pd.read_csv("cevre-meteorology_observation_202012.csv",encoding= 'ISO-8859-9',engine='python')
link24 = pd.read_csv("cevre-meteorology_observation_202101.csv",encoding= 'ISO-8859-9',engine='python')
link25 = pd.read_csv("cevre-park_location.csv",encoding= 'ISO-8859-9',engine='python')
link26 = pd.read_excel("ekonomi-2016-yl-mahallem-istanbul-ses-skorlar.xlsx",encoding= 'ISO-8859-9')
link27 = pd.read_excel("enerji-igda-bina-bilgileri.xlsx",encoding= 'unicode_escape',sheet_name='İGDAŞ Bina Bilgileri')
link28 = pd.read_excel("enerji-ilce-baznda-yllara-gore-doalgaz-tuketim-miktar-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='Tüketim verileri(m3)')
link29 = pd.read_excel("enerji-ilcelere-gore-abone-saylar-tr-en.xlsx",encoding= 'ISO-8859-9',sheet_name='İlçe Abone Sayı')
link30 = pd.read_excel("enerji-istanbul-gune-enerji-santralleri-uretim-miktarlar.xlsx",encoding= 'unicode_escape',sheet_name='Ges Üretim Miktarları')
link31 = pd.read_csv("guvenlik-2017-yl-mahalle-bazl-bina-saylar.csv",encoding= 'ISO-8859-9',engine='python',sep=";")
link32 = pd.read_excel("guvenlik-istanbulsonbiryldepremverisi.xlsx",encoding= 'ISO-8859-9',sheet_name='Son depremler')
link33 = pd.read_excel("guvenlik-itfaiye-konum-verisi.xlsx",encoding= 'ISO-8859-9',sheet_name='istasyonlar')
link34 = pd.read_excel("guvenlik-mavidepo3vdiuserprofilemeral.akardesktopsektor-ve-ilce-baznda-birinci-snf-gayrishhi-muessese-sa.xlsx",encoding= 'ISO-8859-9')
link35 = pd.read_csv("insan-2ibbwifi-lokasyon-kategorisine-gore-veri-kullanmv2.csv",encoding= 'ISO-8859-9',engine='python',sep=";")
link36 = pd.read_excel("insan-2019-yl-ilce-bazl-okuma-yazma-bilen-bilmeyen-kii-says.xlsx",encoding= 'ISO-8859-9')
link37 = pd.read_csv("insan-assistance_university.csv",engine='python')
link38 = pd.read_csv("insan-ibb_wifi_subscriber.csv",encoding= 'ISO-8859-9',engine='python')
link39 = pd.read_csv("insan-ibbwifi-ilce-veya-mobil-lokasyona-gore-yeni-abonelik-istatistikleri.csv",encoding= 'ISO-8859-9',engine='python')
link40 = pd.read_csv("insan-ibbwifi-lokasyon-kategorisine-gore-veri-kullanm.csv",encoding= 'ISO-8859-9',engine='python')
link41 = pd.read_csv("mobilite-gunluk-arac-saym.csv",encoding= 'ISO-8859-9',engine='python' ,sep=";")
link42 = pd.read_csv("mobilite-hourly_transportation_202001.csv",encoding= 'ISO-8859-9',engine='python')
link43 = pd.read_csv("mobilite-hourly_transportation_202002.csv",encoding= 'ISO-8859-9',engine='python')
link44 = pd.read_csv("mobilite-hourly_transportation_202003.csv",encoding= 'ISO-8859-9',engine='python')
link45 = pd.read_csv("mobilite-hourly_transportation_202004.csv",encoding= 'ISO-8859-9',engine='python')
link46 = pd.read_csv("mobilite-hourly_transportation_202005.csv",encoding= 'ISO-8859-9',engine='python')
link47 = pd.read_csv("mobilite-hourly_transportation_202006.csv",encoding= 'ISO-8859-9',engine='python') 
link48 = pd.read_csv("mobilite-hourly_transportation_202007.csv",encoding= 'ISO-8859-9',engine='python')
link49 = pd.read_csv("mobilite-hourly_transportation_202008.csv",encoding= 'ISO-8859-9',engine='python')
link50 = pd.read_csv("mobilite-hourly_transportation_202009.csv",encoding= 'ISO-8859-9',engine='python')
link51 = pd.read_csv("mobilite-hourly_transportation_202010.csv",encoding= 'ISO-8859-9',engine='python')
link52 = pd.read_csv("mobilite-hourly_transportation_202011.csv",encoding= 'ISO-8859-9',engine='python')
link53 = pd.read_csv("mobilite-hourly_transportation_202012.csv",encoding= 'ISO-8859-9',engine='python')
link54 = pd.read_csv("mobilite-hourly_transportation_202101.csv",encoding= 'ISO-8859-9',engine='python')
link55 = pd.read_excel("mobilite-ispark-otoparklarna-ait-bilgiler.xlsx",encoding= 'ISO-8859-9',sheet_name='İSPARK Otoparklarına Ait B.')
link56 = pd.read_excel("mobilite-rayl-sistem-inaat-ilerleme-oranlar.xlsx",encoding= 'ISO-8859-9')
link57 = pd.read_excel("mobilite-rayl-sistemler-cekmekoy-sultanbeyli-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Çekmeköy Sultanbeyli Metro Hat')
link58 = pd.read_excel("mobilite-rayl-sistemler-dudullu-bostanc-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Dudullu-Bostancı Metro Hattı B.')
link59 = pd.read_excel("mobilite-rayl-sistemlere-ait-aktarma-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Raylı Sistem Aktarma Bilgileri')
link60 = pd.read_excel("mobilite-rayl-sistemlere-ait-hat-uzunluk-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Raylı Sistemler Hat Uzunluk B.')
link61 = pd.read_excel("mobilite-rayl-sistemlere-ait-internet-siteleri.xlsx",encoding= 'ISO-8859-9')
link62 = pd.read_excel("mobilite-rayl-sistemlere-ait-istasyon-bilgileri.xlsx",encoding= 'ISO-8859-9')
link63 = pd.read_excel("mobilite-rayl-sistemlere-ait-tamamlanm-antiye-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Raylı S. Tamamlanmış Şantiye B.')
link64 = pd.read_excel("mobilite-rayl-sistemler-eminonu-alibeykoy-tramvay-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Eminönü - Alibeyköy Tramvay Hat')
link65 = pd.read_excel("mobilite-rayl-sistemler-hastane-yenidoan-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Hastane Yenidoğan Metro Hattı B')
link66 = pd.read_excel("mobilite-rayl-sistemler-ikitelli-atakoy-metro-hatt-verisi.xlsx",encoding= 'ISO-8859-9',sheet_name='İkitelli-Ataköy Metro Hattı B.')
link67 = pd.read_excel("mobilite-rayl-sistemler-kabata-mecidiyekoy-mahmutbey-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Kabataş Mköy Mbey Metro Hattı B')
link67 = pd.read_excel("mobilite-rayl-sistemler-kaynarca-tuzla-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Kaynarca Tuzla Metro Hattı B')
link68 = pd.read_excel("mobilite-rayl-sistemler-kirazl-halkal-istasyonu-dier-hatlarla-balant-noktalar.xlsx",encoding= 'ISO-8859-9',sheet_name='Kirazlı-Halkalı İ. Bağlantı N.')
link69 = pd.read_excel("mobilite-rayl-sistemler-kirazl-halkal-metro-hatt-ilce-istasyon-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Kirazlı-Halkalı İlçe İstasyon B')
link70 = pd.read_excel("mobilite-rayl-sistemler-m7-kabata-mecidiyekoy-mahmutbey-metro-hatt-otopark-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Kabataş Mköy Mbey Otopark B.')
link71 = pd.read_excel("mobilite-rayl-sistemler-pendik-kaynarca-hastane-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Pendik Kaynarca Hastane Metro H')
link72 = pd.read_excel("mobilite-rayl-sistemler-umraniye-ataehir-goztepe-metro-hatt-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='Ümraniye Ataşehir Göztepe Metro')
link73 = pd.read_csv("mobilite-traffic_announcement.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link74 = pd.read_csv("mobilite-traffic_density_202007.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link75 = pd.read_csv("mobilite-traffic_density_202008.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link76 = pd.read_csv("mobilite-traffic_density_202009.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link77 = pd.read_csv("mobilite-traffic_density_202010.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link78 = pd.read_csv("mobilite-traffic_density_202011.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link79 = pd.read_csv("mobilite-traffic_density_202012.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link80 = pd.read_csv("mobilite-traffic_density_202101.csv",encoding= 'ISO-8859-9',sep=',',error_bad_lines=False,engine='python')
link81 = pd.read_csv("yasam-salk-kurum-ve-kurulularna-ait-bilgiler.csv",encoding= 'ISO-8859-9',engine='python')
link82 = pd.read_csv("yasam-theater_play.csv",encoding= 'ISO-8859-9',engine='python')
link83 = pd.read_excel("yonetisim-2018-yl-ilce-bazl-ortalama-hane-halk-buyukluu.xlsx",encoding= 'ISO-8859-9')
link84 = pd.read_excel("yonetisim-2019-yl-belediye-nufuslar.xlsx",encoding= 'ISO-8859-9')
link85 = pd.read_csv("yonetisim-ibb_wifi_subscriber.csv",encoding= 'ISO-8859-9',engine='python')
link86 = pd.read_excel("yonetisim-ibb-dava-bilgileri.xlsx",encoding= 'ISO-8859-9',sheet_name='İBB Dava Bilgileri')
link87 = pd.read_excel("yonetisim-mavidepo3vdiuserprofilemeral.akardesktopsektor-ve-ilce-baznda-birinci-snf-gayrishhi-muessese-sa.xlsx",encoding= 'ISO-8859-9')
link88 = pd.read_excel("MahalleGuncelXLSX.xlsx")
# Out:
# Skipping line 161235: ',' expected after '"'
# Skipping line 228748: Expected 8 fields in line 228748, saw 11
# Skipping line 686221: Expected 8 fields in line 686221, saw 15
# Skipping line 1829854: Expected 8 fields in line 1829854, saw 10
# Skipping line 686452: Expected 8 fields in line 686452, saw 15
# Skipping line 1372865: Expected 8 fields in line 1372865, saw 11
# Skipping line 1830485: Expected 8 fields in line 1830485, saw 9
# Skipping line 2059281: Expected 8 fields in line 2059281, saw 10
# Skipping line 228751: Expected 8 fields in line 228751, saw 11
# Skipping line 1143722: Expected 8 fields in line 1143722, saw 13
# Skipping line 2058665: Expected 8 fields in line 2058665, saw 10

# %%
dosyalar = [link1,link2,link3,link4,link5,link6,link7,link8,link9,link10,link11,link12,link13,link14,link15,
            link16,link17,link18,link19,link20,link21,link22,link23,link24,link25,link26,link27,link28,link29,
            link30,link31,link32,link33,link34,link35,link36,link37,link38,link39,link40,link41,link42,link43,
            link44,link45,link46,link47,link48,link49,link50,link51,link52,link53,link54,link55,link56,link57,
            link58,link59,link60,link61,link62,link63,link64,link65,link66,link67,link68,link69,link70,link71,
            link72,link73,link74,link75,link76,link77,link78,link79,link80,link81,link82,link83,link84,link85,link86,link87]

# %%
link90=pd.read_csv('ilcelerVeMahalleler.csv')

# %%
k=pd.merge(link90,link1, left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","Mahalleler"], how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-73a705e069d1> in <module>
# ----> 1 k=pd.merge(link90,link1, left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","Mahalleler"], how="left")
#
# /opt/jupyterhub/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# /opt/jupyterhub/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# ...

# %%
link89=link88[link88["CityName"]=="İSTANBUL"]
link89
# Out:
#            Id  CityName  CityId    CountyName  CountyId VillageName  \
# 2      289700  İSTANBUL      34  KÜÇÜKÇEKMECE      1823      MERKEZ
# 8      293378  İSTANBUL      34       AVCILAR      2003      MERKEZ
# 27     283974  İSTANBUL      34      ESENYURT      2053      MERKEZ
# 73     287208  İSTANBUL      34         FATİH      1327      MERKEZ
# 113    302491  İSTANBUL      34       ÇATALCA      1237      MERKEZ
# ...       ...       ...     ...           ...       ...         ...
# 30485  302358  İSTANBUL      34      ÜMRANİYE      1852      MERKEZ
# 30486  302482  İSTANBUL      34  BÜYÜKÇEKMECE      1782      MERKEZ
# 30516  297693  İSTANBUL      34  KÜÇÜKÇEKMECE      1823      MERKEZ
# 30578  302329  İSTANBUL      34         ŞİŞLİ      1663      MERKEZ
# 30591  293402  İSTANBUL      34      BAĞCILAR      2004      MERKEZ
#
#        VillageId  IsMunicipality  MunicipalityId         MunicipalityName  \
# 2          16674            True            2276  KÜÇÜKÇEKMECE BELEDİYESİ
# ...

# %%
link88["MobileUser"]
# Out:
# 0            NaN
# 1         3830.0
# 2            NaN
# 3          740.0
# 4         6030.0
#           ...
# 30673    21370.0
# 30674     1470.0
# 30675        NaN
# 30676        NaN
# 30677     1030.0
# Name: MobileUser, Length: 30678, dtype: float64

# %%
link90 =link89[["CountyName","DistrictName"]]

# %%
link90
# Out:
#        CountyName              DistrictName
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB
# 1         AVCILAR         MUSTAFA KEMALPAŞA
# 2        ESENYURT         SELAHADDİN EYYUBİ
# 3           FATİH        YAVUZ SULTAN SELİM
# 4         ÇATALCA                 OVAYENİCE
# ..            ...                       ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU
# 966  BÜYÜKÇEKMECE                   TÜRKOBA
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF
# 968         ŞİŞLİ                İZZET PAŞA
# 969      BAĞCILAR                 KEMALPAŞA
#
# [970 rows x 2 columns]

# %%
IlcelerID = pd.read_csv("IlcelerID.csv").rename(columns={"ID":"IlcelerID"})
MahallelerID = pd.read_csv("MahallelerID.csv").rename(columns={"ID":"MahallelerID"})

# %%
dosyalar2=dosyalar[0].groupby(['Mahalleler','COUNTY_NAME'])['LOCATION_NAME'].count().reset_index()

# %%
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].str.replace('Mahallesi','')
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].replace('i','İ').str.upper()
dosyalar[0]["COUNTY_NAME"]=dosyalar[0]["COUNTY_NAME"].replace('i','İ').str.upper()

# %%
dosyalar[0]

# %%
link90.to_csv('ilcelerVeMahalleler.csv',index=False)

# %%
k=pd.merge(link90,dosyalar2, left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","Mahalleler"], how="left")

# %%
k.info()

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="rrtfgdf")
location = geolocator.reverse(" 41.080041, 29.011473")

# %%
location.raw
# Out:
# {'place_id': 71115818,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 6388694087,
#  'lat': '41.0805554',
#  'lon': '29.0111789',
#  'display_name': 'Havabus first stop, Eski Büyükdere Cd., Esentepe Mahallesi, Şişli, İstanbul, Marmara Bölgesi, 34394, Türkiye',
#  'address': {'highway': 'Havabus first stop',
#   'road': 'Eski Büyükdere Cd.',
#   'neighbourhood': 'Esentepe Mahallesi',
#   'town': 'Şişli',
#   'province': 'İstanbul',
#   'region': 'Marmara Bölgesi',
#   'postcode': '34394',
#   'country': 'Türkiye',
#   'country_code': 'tr'},
#  'boundingbox': ['41.0805054', '41.0806054', '29.0111289', '29.0112289']}

# %%
dosyalar = [link1,link2,link3,link4,link5,link6,link7,link8,link9,link10,link11,link12,link13,link14,link15,
            link16,link17,link18,link19,link20,link21,link22,link23,link24,link25,link26,link27,link28,link29,
            link30,link31,link32,link33,link34,link35,link36,link37,link38,link39,link40,link41,link42,link43,
            link44,link45,link46,link47,link48,link49,link50,link51,link52,link53,link54,link55,link56,link57,
            link58,link59,link60,link61,link62,link63,link64,link65,link66,link67,link68,link69,link70,link71,
            link72,link73,link74,link75,link76,link77,link78,link79,link80,link81,link82,link83,link84,link85,link86,link87]

# %%
#####################MAHALLELER##########################
mahalles = []

for i in dosyalar:
    cols = i.columns
    if "Mahalle" in cols:
        for j in i.Mahalle.unique():
            j = str(j).upper()
            j = j.replace("I","İ")
            mahalles.append(j)
            
    if "NEIGHBORHOOD_NAME" in cols:
        for j in i.NEIGHBORHOOD_NAME.unique():
            j = str(j).upper()
            j = j.replace("I","İ")
            mahalles.append(j)        
            
mahalles = list(set(mahalles))
mahalles = mahalles[1:]

turkcedict = {"Å\x9e" : "Ş",        #Ç İ , Ğ ,Ö Ş Ü
             "Ä°" : "İ",            #ığşüöç
             "Ä\x9e" : "Ğ",
             "Ã\x96" : "Ö",
             "Ã\x9c" : "Ü",
             "Ã\x87" : "Ç"}

for i,j in enumerate(mahalles):
    for h in turkcedict.keys():
        mahalles[i] = mahalles[i].replace(h,turkcedict[h])
        
mahalles = list(set(mahalles))
        
MahallelerID = pd.DataFrame(mahalles , columns=["Mahalleler"])
MahallelerID["ID"] = MahallelerID.index 
MahallelerID = MahallelerID[MahallelerID.columns[::-1]]
MahallelerID.to_csv("MahallelerID.csv" , index=False)

#####################ILCELER##########################

ilces = []

for i in dosyalar:
    cols = i.columns
    if "İlçe" in cols:
        for j in i.İlçe.unique():
            j = str(j).upper()
            j = j.replace("I","İ")
            ilces.append(j)
            
    if "COUNTY_NAME" in cols:
        for j in i.COUNTY_NAME.unique():
            j = str(j).upper()
            j = j.replace("I","İ")
            ilces.append(j)        

ilces = list(set(ilces))

turkcedict = {"Å\x9e" : "Ş",        #Ç İ , Ğ ,Ö Ş Ü
             "Ä°" : "İ",            #ığşüöç
             "Ä\x9e" : "Ğ",
             "Ã\x96" : "Ö",
             "Ã\x9c" : "Ü",
             "Ã\x87" : "Ç"}

for i,j in enumerate(ilces):
    for h in turkcedict.keys():
        ilces[i] = ilces[i].replace(h,turkcedict[h])

        
        
Ilcelerdict = {"B.ÇEKMECE" : "BÜYÜKÇEKMECE",
               "K.ÇEKMECE" : "KÜÇÜKÇEKMECE", 
               "G.O.PAŞA"  : "GAZİOSMANPAŞA",
               "EYÜPSULTAN"      : "EYÜP"}                                       

for i,j in enumerate(ilces):
    for h in Ilcelerdict.keys():
        ilces[i] = ilces[i].replace(h,Ilcelerdict[h]) 
        
ilces = list(set(ilces))
        
IlcelerID = pd.DataFrame(ilces , columns=["Ilceler"])
IlcelerID["ID"] = IlcelerID.index 
IlcelerID = IlcelerID[IlcelerID.columns[::-1]]
IlcelerID.to_csv("IlcelerID.csv" , index=False)

# %%
#####################MAHALLELER##########################
import warnings
warnings.filterwarnings("ignore")

turkcedict = {"Å\x9e" : "Ş",        #Ç İ , Ğ ,Ö Ş Ü
             "Ä°" : "İ",            #ığşüöç
             "Ä\x9e" : "Ğ",
             "Ã\x96" : "Ö",
             "Ã\x9c" : "Ü",
             "Ã\x87" : "Ç"}

for a,i in enumerate(dosyalar):
    cols = i.columns
    if "Mahalle" in cols:
        for k,j in enumerate(i.Mahalle):
            for h in turkcedict.keys():
                dosyalar[a].Mahalle[k] = str(i.Mahalle[k]).replace(h,turkcedict[h])
            
        
    if "NEIGHBORHOOD_NAME" in cols:
        for k,j in enumerate(i.NEIGHBORHOOD_NAME):
            for h in turkcedict.keys():
                dosyalar[a].NEIGHBORHOOD_NAME[k] = str(i.NEIGHBORHOOD_NAME[k]).replace(h,turkcedict[h])
            


for a,i in enumerate(dosyalar):
    cols = i.columns
    if "Mahalle" in cols:
        for k,j in enumerate(i.Mahalle):
            dosyalar[a].Mahalle[k] = str(i.Mahalle[k]).upper().replace("I","İ") # replace('i','İ').str.upper()

            
    if "NEIGHBORHOOD_NAME" in cols:
        for k,j in enumerate(i.NEIGHBORHOOD_NAME):
            dosyalar[a].NEIGHBORHOOD_NAME[k] = str(i.NEIGHBORHOOD_NAME[k]).upper().replace("I","İ")
      
            



#####################ILCELER##########################

for a,i in enumerate(dosyalar):
    cols = i.columns
    if "İlçe" in cols:
        for k,j in enumerate(i.İlçe):
            for h in turkcedict.keys():
                dosyalar[a].İlçe[k] = str(i.İlçe[k]).replace(h,turkcedict[h])
            
        
    if "COUNTY_NAME" in cols:
        for k,j in enumerate(i.COUNTY_NAME):
            for h in turkcedict.keys():
                dosyalar[a].COUNTY_NAME[k] = str(i.COUNTY_NAME[k]).replace(h,turkcedict[h])
            


for a,i in enumerate(dosyalar):
    cols = i.columns
    if "İlçe" in cols:
        for k,j in enumerate(i.İlçe):
            dosyalar[a].İlçe[k] = str(i.İlçe[k]).upper().replace("I","İ")

            
    if "COUNTY_NAME" in cols:
        for k,j in enumerate(i.COUNTY_NAME):
            dosyalar[a].COUNTY_NAME[k] = str(i.COUNTY_NAME[k]).upper().replace("I","İ")
            
Ilcelerdict = {"B.ÇEKMECE" : "BÜYÜKÇEKMECE",
               "K.ÇEKMECE" : "KÜÇÜKÇEKMECE", 
               "G.O.PAŞA"  : "GAZİOSMANPAŞA",
               "EYÜPSULTAN": "EYÜP"}     

for a,i in enumerate(dosyalar):
    cols = i.columns
    if "İlçe" in cols:
        for k,j in enumerate(i.İlçe):
            for h in Ilcelerdict.keys():
                dosyalar[a].İlçe[k] = str(i.İlçe[k]).replace(h,Ilcelerdict[h])
                
    
    if "COUNTY_NAME" in cols:
        for k,j in enumerate(i.COUNTY_NAME):
            for h in Ilcelerdict.keys():
                dosyalar[a].COUNTY_NAME[k] = str(i.COUNTY_NAME[k]).replace(h,Ilcelerdict[h])

# %%
for a,i in enumerate(dosyalar):
    cols = i.columns
    
    if "İlçe" in cols:
        dosyalar[a] = i.rename(columns={"İlçe":"Ilceler"})
        
    if "COUNTY_NAME" in cols:
        dosyalar[a] = i.rename(columns={"COUNTY_NAME":"Ilceler"})
        
    if "Mahalle" in cols:
        dosyalar[a] = i.rename(columns={"Mahalle":"Mahalleler"})
        
    if "NEIGHBORHOOD_NAME" in cols:
        dosyalar[a] = i.rename(columns={"NEIGHBORHOOD_NAME":"Mahalleler"})

# %%
#pd.merge(dosyalar[1],MahallelerID,IlcelerID , on=["Mahalleler"] , how="outer")

# %%
dosyalar[40]["X Koordinati"]=dosyalar[40]["X Koordinati"].str.replace(',','.')
dosyalar[40]["Y Koordinati"]=dosyalar[40]["Y Koordinati"].str.replace(',','.')

# %%
dosyalar[40]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="rrtfgdf")
location = geolocator.reverse(" 40.9950792, 28.92097089")

# %%
location.raw
# Out:
# {'place_id': 225159560,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 676231150,
#  'lat': '40.995096231327544',
#  'lon': '28.920782434658285',
#  'display_name': '10. Yıl Caddesi, Yedikule, Yedikule Mahallesi, Fatih, İstanbul, Marmara Bölgesi, 34107, Türkiye',
#  'address': {'road': '10. Yıl Caddesi',
#   'neighbourhood': 'Yedikule',
#   'city_district': 'Yedikule Mahallesi',
#   'town': 'Fatih',
#   'province': 'İstanbul',
#   'region': 'Marmara Bölgesi',
#   'postcode': '34107',
#   'country': 'Türkiye',
#   'country_code': 'tr'},
#  'boundingbox': ['40.9923671', '40.9998307', '28.9197672', '28.9208016']}

# %%
#x=dosyalar[0].LONGITUDE
#y=dosyalar[0].LATITUDE
#L1=dosyalar[0].LONGITUDE,dosyalar[0].LATITUDE

# %%
#dosyalar[0].loc[0,'LATITUDE']
# Out:
# 41.039792

# %%
def enlemboylam(filename,Latitude='Latitude',Longitude='Longitude'):
    for i in range(len(filename)):
        lon= filename.loc[i,Longitude]
        lat= filename.loc[i,Latitude]
        k='{},{}'.format(lat,lon)
        raws=geolocator.reverse(k).raw['address']
        try:
            filename.loc[i,'Mahalleler']=raws['neighbourhood']
        except:
            try:
                filename.loc[i,'Mahalleler']=raws['village']
            except:
                try:
                    filename.loc[i,'Mahalleler']=raws['city_district']
                except:
                    pass
        try:
            filename.loc[i,'COUNTY_NAME']=raws['county']
        except:
            try:
                filename.loc[i,'COUNTY_NAME']=raws['town']
            except:
                pass
        if (i%50)==0:
            print(i,k)
    return print('son')

# %%
enlemboylam(dosyalar[0],Latitude='LATITUDE',Longitude='LONGITUDE')

# %%
#dosyalar[0].to_csv('dosyalar0abak.csv',index=False)

# %%
dosyalar[0]
# Out:
#                                      LOCATION_NAME  LONGITUDE   LATITUDE
# 0                            007-Kumburgaz Itfaiye  28.468128  41.039792
# 1                 024-Beykoz Koru Sosyal Tesisleri  29.094437  41.131533
# 2                            75. YIL YÃZME HAVUZU  28.902058  41.095632
# 3    059-Zincirlikuyu Mezarliklar Daire Baskanligi  29.003291  41.042540
# 4        ÃSKÃDAR TÃRK-Ä°SLAM SANATLARI MERKEZÄ°  29.011790  41.023750
# ..                                             ...        ...        ...
# 902                          060-Edirnekapi Trafik  28.928432  41.030349
# 903                           SANCAKTEPE SAMANDIRA  29.227160  40.986580
# 904                 TÃRKÄ°YE YEÅÄ°LAY CEMÄ°YETÄ°  28.721899  40.981589
# 905                      029-Sile Engelliler Kampi  29.471361  41.187223
# 906                    059-Besyuzevler Mezarliklar  28.883214  41.074559
#
# [907 rows x 3 columns]

# %%
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].str.replace('Mahallesi','')
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].str.strip()
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].str.replace('i','İ').str.upper()
dosyalar[0]["COUNTY_NAME"]=dosyalar[0]["COUNTY_NAME"].str.replace('i','İ').str.upper()
dosyalar[0]["COUNTY_NAME"]=dosyalar[0]["COUNTY_NAME"].str.replace('i','İ').str.upper()

# %%
dosyalar0=dosyalar[0].groupby(['Mahalleler','COUNTY_NAME'])['LOCATION_NAME'].count().reset_index()

# %%
k0=pd.merge(link90,dosyalar0, left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","Mahalleler"], how="left")

# %%
k0.info()

# %%
k0=k0.rename(columns={'LOCATION_NAME': 'afet_ibblocnamesayi'})

# %%
#link1'de yani ibb loc name csv'sinde 383 değer varmış 361'i dolmuş.

# %%
k0=pd.read_csv('k0.csv')

# %%
dosyalar[1]
# Out:
#              ID                                        NAME  COUNTY_NAME  \
# 0       1133899                    Kadıköy Musevi Mezarlığı      KADIKÖY
# 1    1500000039                         Ovayenice Mezarlığı      ÇATALCA
# 2     113001361                         Dursunköy Mezarlığı   ARNAVUTKÖY
# 3    1500000103                    Yukarı Baklacı Mezarlığı       BEYKOZ
# 4       1133902                           Ayvalık Mezarlığı  ZEYTİNBURNU
# ..          ...                                         ...          ...
# 609     1133901  Silivrikapı Balıklı Rum Ortadoks Mezarlığı  ZEYTİNBURNU
# 610  1500000080                         Necatibey Mezarlığı   EYÜPSULTAN
# 611  1500000085                     Yukarı Ağaçlı Mezarlığı   EYÜPSULTAN
# 612     1133497                       Silivrikapı Mezarlığı  ZEYTİNBURNU
# 613     1133490                         Şişli Rum Mezarlığı        ŞİŞLİ
#
#     NEIGHBORHOOD_NAME
# 0           HASANPAŞA
# 1           OVAYENİCE
# ...

# %% [raw]
# dosyalar[1]["Mahalleler"]=dosyalar[1]["Mahalleler"].str.replace('Mahallesi','')
# dosyalar[1]["Mahalleler"]=dosyalar[1]["Mahalleler"].str.strip()
# dosyalar[1]["Mahalleler"]=dosyalar[1]["Mahalleler"].str.replace('i','İ').str.upper()
# dosyalar[1]["COUNTY_NAME"]=dosyalar[1]["COUNTY_NAME"].str.replace('i','İ').str.upper()

# %%
dosyalar1=dosyalar[1].groupby(['NEIGHBORHOOD_NAME','COUNTY_NAME'])['NAME'].count().reset_index()
# Out:
#     NEIGHBORHOOD_NAME   COUNTY_NAME  NAME
# 0              19.May  BÜYÜKÇEKMECE     1
# 1     ABDURRAHMANGAZİ   SULTANBEYLİ     2
# 2          ADEM YAVUZ      ÜMRANİYE     1
# 3       ADNAN KAHVECİ    BEYLİKDÜZÜ     1
# 4            AHMEDİYE  BÜYÜKÇEKMECE     1
# ..                ...           ...   ...
# 381          İZZETTİN       ÇATALCA     2
# 382         İÇERENKÖY      ATAŞEHİR     1
# 383            ŞAMLAR    BAŞAKŞEHİR     1
# 384            ŞEYHLİ        PENDİK     2
# 385          ŞUAYİPLİ          ŞİLE     7
#
# [386 rows x 3 columns]

# %%
dosyalar1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NEIGHBORHOOD_NAME  386 non-null    object
#  1   COUNTY_NAME        386 non-null    object
#  2   NAME               386 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 9.2+ KB

# %%
dosyalar1=dosyalar1.rename(columns={'NAME': 'afet_mezarliksayi'})

# %%
k0.drop(['Mahalleler','COUNTY_NAME'],axis=1,inplace=True)

# %%
k1=pd.merge(k0,dosyalar1,left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","NEIGHBORHOOD_NAME"], how="left")
k1.drop(['NEIGHBORHOOD_NAME','COUNTY_NAME'],axis=1,inplace=True)

# %%
#k1.to_csv('k1.csv',index=False)

# %% [raw]
# dosyalar[5][dosyalar[5]['Yıl']!=2019]

# %%
k2=pd.merge(k1,dosyalar[5],left_on=["CountyName"] ,right_on=["İlçe"], how="left")
k2.drop(['Yıl','İlçe'],axis=1,inplace=True)
k2.to_csv('k2.csv',index=False)

# %%
k2
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza  Giderilen Arıza
# 0                  NaN          NaN              NaN
# 1                  NaN      18261.0          18122.0
# ...

# %% [raw]
# dosyalar5=dosyalar[5].rename(columns={'Gelen Arıza': 'cevre_gelcagrisayisi_y19','Giderilen Arıza': 'cevre_gidcagrisayisi_y19'})

# %%
dosyalar[6]['Mahalle'].str.endswith(' MAH')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993     True
# 994     True
# 995     True
# 996     True
# 997     True
# Name: Mahalle, Length: 998, dtype: object

# %%
df2=dosyalar[6]['Mahalle'].str.split(" ",expand=True,)

# %%
df2
# Out:
#                        0      1         2     3     4     5
# 0    ADALAR-STANDARTDIŞI  ADRES      None  None  None  None
# 1                 BURGAZ  ADASI      None  None  None  None
# 2                HEYBELİ    ADA      None  None  None  None
# 3                 KINALI    ADA      None  None  None  None
# 4                  MADEN  MAH.-  BÜYÜKADA  None  None  None
# ..                   ...    ...       ...   ...   ...   ...
# 993                 PAŞA    MAH      None  None  None  None
# 994            TEŞVİKİYE    MAH      None  None  None  None
# 995                YAYLA    MAH      None  None  None  None
# 996                İNÖNÜ    MAH      None  None  None  None
# 997                İZZET   PAŞA       MAH  None  None  None
#
# [998 rows x 6 columns]

# %%
for i in range(len(df2)):
    for j in range(6):
        if (df2.loc[i,j]=='MAH') | (df2.loc[i,j]=='MAH]') | (df2.loc[i,j]=='MAH.'):
            df2.loc[i,j]=None
dosyalar[0]["Mahalleler"]=dosyalar[0]["Mahalleler"].str.replace('Mahallesi','')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       970 non-null    object
#  1   1       217 non-null    object
#  2   2       35 non-null     object
#  3   3       4 non-null      object
#  4   4       1 non-null      object
#  5   5       0 non-null      object
# dtypes: object(6)
# memory usage: 46.9+ KB

# %%
df2[5].fillna('',inplace=True)
df2[4].fillna('',inplace=True)
df2[3].fillna('',inplace=True)
df2[2].fillna('',inplace=True)
df2[1].fillna('',inplace=True)
df2[0].fillna('',inplace=True)
df2[6]=df2[0].map(str)+' '+df2[1].map(str)+' '+df2[2].map(str)+' '+df2[3].map(str)+' '+df2[4].map(str)+' '+df2[5].map(str)
df2=df2[6]

# %%
dosyalar[6]['Mahalle']=df2

# %%
dosyalar[6]
# Out:
#       Yıl    İlçe                        Mahalle  Gelen Arıza  \
# 0    2019  ADALAR  ADALAR-STANDARTDIŞI ADRES                1
# 1    2019  ADALAR               BURGAZ ADASI               95
# 2    2019  ADALAR                HEYBELİ ADA              109
# 3    2019  ADALAR                 KINALI ADA              108
# 4    2019  ADALAR        MADEN MAH.- BÜYÜKADA             168
# ..    ...     ...                            ...          ...
# 993  2019   ŞİŞLİ                      PAŞA               264
# 994  2019   ŞİŞLİ                 TEŞVİKİYE               344
# 995  2019   ŞİŞLİ                     YAYLA               190
# 996  2019   ŞİŞLİ                     İNÖNÜ               129
# 997  2019   ŞİŞLİ                 İZZET PAŞA              197
#
#      Cevaplanan Arıza
# 0                 NaN
# 1                95.0
# 2               109.0
# 3               108.0
# 4               166.0
# ..                ...
# 993             264.0
# 994             344.0
# ...

# %%
k3=pd.merge(k2,dosyalar[6], left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalle"], how="left")

# %%
k3=k3.rename(columns={'Gelen Arıza_y': 'cevre_kanalgelcagrisayisi_y19'})
k3=k3.rename(columns={'Cevaplanan Arıza': 'cevre_kanalgidcagrisayisi_y19'})

# %%
k3=k3.drop(columns=["Yıl", "İlçe","Mahalle"])

# %%
k3
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
dosyalar[6]["Mahalle"]=dosyalar[6]["Mahalle"].str.strip()

# %%
k3=k3.drop(columns=["Yıl", "İlçe","Mahalle","Gelen Arıza_y","Cevaplanan Arıza"])

# %% [raw]
# dosyalar6=dosyalar[6].rename(columns={'Gelen Arıza': 'cevre_kanalgelcagrisayisi_y19'})
# dosyalar6=dosyalar[6].rename(columns={'Cevaplanan Arıza': 'cevre_kanalgidcagrisayisi_y19'})

# %% [raw]
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace('ADRES','')
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace(' MAH','')
# #hacı mahmut, mahmudiye
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace('ADALAR','')
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace('.','')
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.strip()
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.strip()

# %% [raw]
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace('Mahallesi','')
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.strip()
# dosyalar6["Mahalleler"]=dosyalar6["Mahalleler"].str.replace('i','İ').str.upper()

# %%
#dosyalar[7] için düzenleme
df3=dosyalar[7]['Mahalle'].str.split(" ",expand=True,)

# %%
df3
# Out:
#                        0      1         2 3  4  5
# 0    ADALAR-STANDARTDIŞI  ADRES
# 1                 BURGAZ  ADASI
# 2                HEYBELİ    ADA
# 3                 KINALI    ADA
# 4                  MADEN  MAH.-  BÜYÜKADA
# ..                   ...    ...       ... .. .. ..
# 992            TEŞVİKİYE
# 993                YAYLA
# 994                İNÖNÜ
# 995                İZZET   PAŞA
# 996
#
# [997 rows x 6 columns]

# %%
for i in range(len(df3)):
    for j in range(6):
        if (df3.loc[i,j]=='MAH') | (df3.loc[i,j]=='MAH]') | (df3.loc[i,j]=='MAH.'):
            df3.loc[i,j]=None

# %%
df3[5].fillna('',inplace=True)
df3[4].fillna('',inplace=True)
df3[3].fillna('',inplace=True)
df3[2].fillna('',inplace=True)
df3[1].fillna('',inplace=True)
df3[0].fillna('',inplace=True)
df3[6]=df3[0].map(str)+' '+df3[1].map(str)+' '+df3[2].map(str)+' '+df3[3].map(str)+' '+df3[4].map(str)+' '+df3[5].map(str)
df3=df3[6]

# %%
dosyalar[7]['Mahalle']=df3

# %%
dosyalar[7]["Mahalle"]=dosyalar[7]["Mahalle"].str.strip()

# %%
dosyalar[7]
# Out:
#       Yıl    İlçe                    Mahalle  Gelen Arıza  Cevaplanan Arıza
# 0    2019  ADALAR  ADALAR-STANDARTDIŞI ADRES            1               NaN
# 1    2019  ADALAR               BURGAZ ADASI          106             106.0
# 2    2019  ADALAR                HEYBELİ ADA          126             117.0
# 3    2019  ADALAR                 KINALI ADA          148             142.0
# 4    2019  ADALAR       MADEN MAH.- BÜYÜKADA          155             140.0
# ..    ...     ...                        ...          ...               ...
# 992  2019   ŞİŞLİ                  TEŞVİKİYE          483             483.0
# 993  2019   ŞİŞLİ                      YAYLA          144             144.0
# 994  2019   ŞİŞLİ                      İNÖNÜ          180             180.0
# 995  2019   ŞİŞLİ                 İZZET PAŞA          240             240.0
# 996  2019   ŞİŞLİ                                       1               1.0
#
# [997 rows x 5 columns]

# %%
k4=pd.merge(k3,dosyalar[7], left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalle"], how="left")

# %%
k4=k4.drop(columns=["Yıl", "İlçe","Mahalle"])

# %%
k4=k4.rename(columns={'Gelen Arıza': 'cevre_sugelcagrisayisi_y19'})
k4=k4.rename(columns={'Cevaplanan Arıza': 'cevre_sucevcagrisayisi_y19'})

# %%
k4
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %% [raw]
# k4=pd.merge(k3,dosyalar6, left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalleler"], how="left")
# k4=k4.rename(columns={'Gelen Arıza': 'cevre_kanalgelcagrisayisi_y19'})
# k4=k4.drop(columns=["Yıl", "İlçe","Mahalleler"])
# k4["DistrictName"]=k4["DistrictName"].str.replace('İ','I')
# dosyalar7=dosyalar[7].rename(columns={'Gelen Arıza': 'cevre_sugelcagrisayisi_y19'})
# dosyalar7=dosyalar[7].rename(columns={'Cevaplanan Arıza': 'cevre_sugelcagrisayisi_y19'})
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace('ADRES','')
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace(' MAH','')
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace('ADALAR','')
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace('.','')
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.strip()
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.strip()
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace('Mahallesi','')
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.strip()
# dosyalar7["Mahalleler"]=dosyalar7["Mahalleler"].str.replace('i','İ').str.upper()
# k5=pd.merge(k4,dosyalar7, left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalleler"], how="left")
# k5=k5.rename(columns={'Gelen Arıza': 'cevre_sugelcagrisayisi_y19'})
# k5=k5.drop(columns=["Yıl", "İlçe","Mahalleler"])

# %%
dosyalar[8].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   İlçe                     954 non-null    object
#  1   Mahalle                  954 non-null    object
#  2   Gelen Çağrı Sayısı       954 non-null    int64
#  3   Cevaplanan Çağrı Sayısı  951 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 29.9+ KB

# %%
df3=dosyalar[8]['Mahalle'].str.split(" ",expand=True,)

# %%
dosyalar[8]
# Out:
#        İlçe               Mahalle  Gelen Çağrı Sayısı  Cevaplanan Çağrı Sayısı
# 0    ADALAR          BURGAZ ADASI                  17                     14.0
# 1    ADALAR           HEYBELİ ADA                  24                     23.0
# 2    ADALAR            KINALI ADA                  23                     23.0
# 3    ADALAR  MADEN MAH.- BÜYÜKADA                  47                     42.0
# 4    ADALAR  NİZAM MAH.- BÜYÜKADA                  44                     35.0
# ..      ...                   ...                 ...                      ...
# 949   ŞİŞLİ              PAŞA MAH                  75                     70.0
# 950   ŞİŞLİ         TEŞVİKİYE MAH                  49                     33.0
# 951   ŞİŞLİ             YAYLA MAH                  22                     16.0
# 952   ŞİŞLİ             İNÖNÜ MAH                  13                     12.0
# 953   ŞİŞLİ        İZZET PAŞA MAH                 119                     99.0
#
# [954 rows x 4 columns]

# %%
for i in range(len(df3)):
    for j in range(6):
        if (df3.loc[i,j]=='MAH') | (df3.loc[i,j]=='MAH]') | (df3.loc[i,j]=='MAH.'):
            df3.loc[i,j]=None

# %%
df3[5].fillna('',inplace=True)
df3[4].fillna('',inplace=True)
df3[3].fillna('',inplace=True)
df3[2].fillna('',inplace=True)
df3[1].fillna('',inplace=True)
df3[0].fillna('',inplace=True)
df3[6]=df3[0].map(str)+' '+df3[1].map(str)+' '+df3[2].map(str)+' '+df3[3].map(str)+' '+df3[4].map(str)+' '+df3[5].map(str)
df3=df3[6]

# %%
dosyalar[8]['Mahalle']=df3

# %%
dosyalar[8]["Mahalle"]=dosyalar[8]["Mahalle"].str.strip()

for i in range(len(dosyalar[8])):
    dosyalar[8]["İlçe"]=dosyalar[8]["İlçe"].str.replace("B.ÇEKMECE","BÜYÜKÇEKMECE")
    dosyalar[8]["İlçe"]=dosyalar[8]["İlçe"].str.replace("K.ÇEKMECE","KÜÇÜKÇEKMECE")
    dosyalar[8]["İlçe"]=dosyalar[8]["İlçe"].str.replace("G.O.PAŞA","GAZİOSMANPAŞA")

# %%
k5=pd.merge(k4,dosyalar[8], left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalle"], how="left")

# %% [raw]
# Ilcelerdict = {"B.ÇEKMECE" : "BÜYÜKÇEKMECE",
#                "K.ÇEKMECE" : "KÜÇÜKÇEKMECE",
#                "G.O.PAŞA"  : "GAZİOSMANPAŞA",
#                "EYÜPSULTAN"      : "EYÜP"}
#
# for i,j in enumerate(dosyalar[8].İlçe):
#     for h in Ilcelerdict.keys():
#         dosyalar[8].İlçe[i] = dosyalar[8].İlçe[i].replace(h,Ilcelerdict[h])
#
# dosyalar[8].İlçe = list(set(dosyalar[8].İlçe))

# %%
# Out:
#         İLÇE ADI MAHALLE ADI SES  SES SKORU
# 0         ADALAR   BURGAZADA   B       62.5
# 1         ADALAR  HEYBELİADA   B       62.5
# 2         ADALAR   KINALIADA   C       37.5
# 3         ADALAR       MADEN   B       62.5
# 4         ADALAR       NİZAM  B+       75.0
# ..           ...         ...  ..        ...
# 954  ZEYTİNBURNU       SÜMER   C       37.5
# 955  ZEYTİNBURNU      TELSİZ   C       37.5
# 956  ZEYTİNBURNU  VELİEFENDİ   C       37.5
# 957  ZEYTİNBURNU   YENİDOĞAN   C       37.5
# 958  ZEYTİNBURNU   YEŞİLTEPE   D       25.0
#
# [959 rows x 4 columns]

# %%
dosyalar[25]
# Out:
#         İLÇE ADI MAHALLE ADI SES  SES SKORU
# 0         ADALAR   BURGAZADA   B       62.5
# 1         ADALAR  HEYBELİADA   B       62.5
# 2         ADALAR   KINALIADA   C       37.5
# 3         ADALAR       MADEN   B       62.5
# 4         ADALAR       NİZAM  B+       75.0
# ..           ...         ...  ..        ...
# 954  ZEYTİNBURNU       SÜMER   C       37.5
# 955  ZEYTİNBURNU      TELSİZ   C       37.5
# 956  ZEYTİNBURNU  VELİEFENDİ   C       37.5
# 957  ZEYTİNBURNU   YENİDOĞAN   C       37.5
# 958  ZEYTİNBURNU   YEŞİLTEPE   D       25.0
#
# [959 rows x 4 columns]

# %%
df3=dosyalar[25]['MAHALLE ADI'].str.split(" ",expand=True,)

# %%
dosyalar[25].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   İLÇE ADI     959 non-null    object
#  1   MAHALLE ADI  959 non-null    object
#  2   SES          959 non-null    object
#  3   SES SKORU    959 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 30.1+ KB

# %%
#mah olmadığı için hata verdi


for i in range(len(df3)):
    for j in range(6):
        if (df3.loc[i,j]=='MAH') | (df3.loc[i,j]=='MAH]') | (df3.loc[i,j]=='MAH.'):
            df3.loc[i,j]=None

# %%
k6=pd.merge(k5,dosyalar[25], left_on=["CountyName","DistrictName"] ,right_on=["İLÇE ADI","MAHALLE ADI"], how="left")
#dosyalar[25]te toplam 959 data varmış 929u geldi sadece 30 fire var. ;) hadi iyisiiiiiiiiiiiin

# %%
k6
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k6=k6.rename(columns={"Gelen Çağrı Sayısı": 'cevre_suzlukgelcagrisayisi'})
k6=k6.rename(columns={'Cevaplanan Çağrı Sayısı': 'cevre_suzlukgidcagrisayisi'})
k6=k6.rename(columns={"SES": 'guvenlik_SES'})
k6=k6.rename(columns={"SES SKORU": 'guvenlik_SES_SCORE-2016'})

# %%
k6=k6.drop(columns=["İlçe", "Mahalle","İLÇE ADI","MAHALLE ADI"])

# %%
k6
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
dosyalar[28]["İLÇE"]=dosyalar[28]["İLÇE"].str.upper()

# %%
k7=pd.merge(k6,dosyalar[28], left_on=["CountyName"] ,right_on=["İLÇE"], how="left")

# %%
k7=k7.drop(columns=["İLÇE"])

# %%
k7=k7.rename(columns={"ABONE SAYI": 'enerji_ilceabonesayi'})

# %%
#dosyalar[28] bitişi
k8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CountyName                     970 non-null    object
#  1   DistrictName                   970 non-null    object
#  2   afet_ibblocnamesayi            361 non-null    float64
#  3   afet_mezarliksayi              379 non-null    float64
#  4   Gelen Arıza_x                  908 non-null    float64
#  5   Giderilen Arıza                908 non-null    float64
#  6   cevre_kanalgelcagrisayisi_y19  778 non-null    float64
#  7   cevre_kanalgidcagrisayisi_y19  778 non-null    float64
#  8   cevre_sugelcagrisayisi_y19     780 non-null    float64
#  9   cevre_sucevcagrisayisi_y19     780 non-null    float64
#  10  cevre_suzlukgelcagrisayisi     822 non-null    float64
#  11  cevre_suzlukgidcagrisayisi     820 non-null    float64
# ...

# %%
dosyalar[30]
# Out:
#         ilce_adi mahalle_adi  mahalle_uavt  1980_oncesi  1980-2000_arasi  \
# 0         ADALAR   BURGAZADA         40139          433              214
# 1         ADALAR  HEYBELİADA         40142          836              347
# 2         ADALAR   KINALIADA         40143          610              244
# 3         ADALAR       MADEN         40140          863              510
# 4         ADALAR       NİZAM         40141          842              426
# ..           ...         ...           ...          ...              ...
# 954  ZEYTİNBURNU       SÜMER         40831           53             1025
# 955  ZEYTİNBURNU      TELSİZ         40839          567              763
# 956  ZEYTİNBURNU  VELİEFENDİ         40836           92             1020
# 957  ZEYTİNBURNU   YENİDOĞAN         40833           31              450
# 958  ZEYTİNBURNU   YEŞİLTEPE         40835           50              726
#
#      2000_sonrasi  1-4 kat_arasi  5-9 kat_arasi  9-19 kat_arasi
# ...

# %%
k8=pd.merge(k7,dosyalar[30], left_on=["CountyName","DistrictName"] ,right_on=["ilce_adi","mahalle_adi"], how="left")

# %%
k8=k8.drop(columns=["ilce_adi","mahalle_adi","mahalle_uavt"])

# %%
k8=k8.rename(columns={"1980_oncesi": 'guvenlik_bina_sayisi_1980_oncesi'})
k8=k8.rename(columns={"1980-2000_arasi": 'guvenlik_bina_sayisi_19802000arasi'})
k8=k8.rename(columns={"2000_sonrasi": 'guvenlik_bina_sayisi_2000_sonrasi'})
k8=k8.rename(columns={"1-4 kat_arasi": 'guvenlik_bina_sayisi_1-4 kat_arasi'})
k8=k8.rename(columns={"5-9 kat_arasi": 'guvenlik_bina_sayisi_5-9 kat_arasi'})
k8=k8.rename(columns={"9-19 kat_arasi": 'guvenlik_bina_sayisi_9-19 kat_arasi'})

# %%
k8
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
dosyalar[35]["İlçeler"]=dosyalar[35]["İlçeler"].str.upper()

# %%
k9=pd.merge(k8,dosyalar[35], left_on=["CountyName"] ,right_on=["İlçeler"], how="left")

# %%
k9=k9.rename(columns={"Bilinmeyen": 'insan_okumabilinmeyensayisi'})
k9=k9.rename(columns={"Okuma Yazma Bilen": 'insan_okumayazmabilensayisi'})
k9=k9.rename(columns={"Okuma Yazma Bilmeyen ": 'insan_okumayazmabilmeyensayisi'})

# %%
k9=k9.drop(columns=["İlçeler"])

# %%
k9
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k9=k9.rename(columns={" Okuma Yazma Bilmeyen": 'insan_okumayazmabilmeyensayisi'})

# %%
k9
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   CountyName                          970 non-null    object
#  1   DistrictName                        970 non-null    object
#  2   afet_ibblocnamesayi                 361 non-null    float64
#  3   afet_mezarliksayi                   379 non-null    float64
#  4   Gelen Arıza_x                       908 non-null    float64
#  5   Giderilen Arıza                     908 non-null    float64
#  6   cevre_kanalgelcagrisayisi_y19       778 non-null    float64
#  7   cevre_kanalgidcagrisayisi_y19       778 non-null    float64
#  8   cevre_sugelcagrisayisi_y19          780 non-null    float64
#  9   cevre_sucevcagrisayisi_y19          780 non-null    float64
#  10  cevre_suzlukgelcagrisayisi          822 non-null    float64
# ...

# %%
k9=k9.rename(columns={"guvenlik_bina_sayisi_1-4 kat_arasi": 'guvenlik_binasayisi1_4katarasi'})
k9=k9.rename(columns={"guvenlik_bina_sayisi_5-9 kat_arasi": 'guvenlik_binasayisi5_9katarasi'})
k9=k9.rename(columns={"guvenlik_bina_sayisi_9-19 kat_arasi": 'guvenlik_binasayisi9_19katarasi'})

# %%
k9
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
dosyalar[36]["COUNTY"].unique()
# Out:
# array(['GÜNGÖREN', 'BAHÇELİEVLER', 'AVCILAR', 'BAŞAKŞEHİR',
#        'GAZİOSMANPAŞA', 'MALTEPE', 'ARNAVUTKÖY', 'ŞİŞLİ', 'FATİH',
#        'ATAŞEHİR', 'BAĞCILAR', 'BEYLİKDÜZÜ', 'ÜSKÜDAR', 'SULTANBEYLİ',
#        'SANCAKTEPE', 'KADIKÖY', 'ZEYTİNBURNU', 'BEYOĞLU', 'ÇEKMEKÖY',
#        'SULTANGAZİ', 'SİLİVRİ', 'ÜMRANİYE', 'TUZLA', 'KÜÇÜKÇEKMECE',
#        'KARTAL', 'BAYRAMPAŞA', 'ESENLER', 'BÜYÜKÇEKMECE', 'EYÜPSULTAN',
#        'SARIYER', 'PENDİK', 'ESENYURT', 'ÇATALCA', 'BEYKOZ', 'ŞİLE',
#        'KAĞITHANE', 'BEŞİKTAŞ', 'BAKIRKÖY', 'ADALAR', 'EYÜP'],
#       dtype=object)

# %%
#burda 50 bin satıra çıktı bunu sefaya sor 
k10=pd.merge(k9,dosyalar[36], left_on=["CountyName"] ,right_on=["COUNTY"], how="left")

# %%
k10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 654087 entries, 0 to 654086
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   CountyName                          654087 non-null  object
#  1   DistrictName                        654087 non-null  object
#  2   afet_ibblocnamesayi                 270942 non-null  float64
#  3   afet_mezarliksayi                   201582 non-null  float64
#  4   Gelen Arıza_x                       602557 non-null  float64
#  5   Giderilen Arıza                     602557 non-null  float64
#  6   cevre_kanalgelcagrisayisi_y19       522901 non-null  float64
#  7   cevre_kanalgidcagrisayisi_y19       522901 non-null  float64
#  8   cevre_sugelcagrisayisi_y19          523179 non-null  float64
#  9   cevre_sucevcagrisayisi_y19          523179 non-null  float64
#  10  cevre_suzlukgelcagrisayisi          564800 non-null  float64
# ...

# %%
dosyalar[82].head()
# Out:
#    İlçe Adı  Ortalama Hanehalkı Büyüklüğü
# 0    Adalar                          2.54
# 1  Bakırköy                          2.87
# 2  Beşiktaş                          2.47
# 3    Beykoz                          3.29
# 4   Beyoğlu                          3.11

# %%
dosyalar[82]["İlçe Adı"]=dosyalar[82]["İlçe Adı"].str.upper()

# %%
k10=pd.merge(k9,dosyalar[82], left_on=["CountyName"] ,right_on=["İlçe Adı"], how="left")

# %%
k10
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k10=k10.rename(columns={"Ortalama Hanehalkı Büyüklüğü": 'yonetisim_orthanebuyuklugu_2018'})

# %%
k10
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k10=k10.drop(columns=["İlçe Adı"])

# %%
dosyalar[84]
# Out:
#       SUBSCRIPTION_DATE SUBSCRIPTION_COUNTY SUBSCRIBER_DOMESTIC_FOREIGN  \
# 0            2019-06-01       BAÅAKÅEHÄ°R                       Yerli
# 1            2018-03-19             MALTEPE                    YabancÄ±
# 2            2017-12-19          ÃEKMEKÃY                       Yerli
# 3            2017-12-30           BAKIRKÃY                       Yerli
# 4            2015-12-26          KAÄITHANE                       Yerli
# ...                 ...                 ...                         ...
# 16960        2018-07-03          SANCAKTEPE                       Yerli
# 16961        2017-12-17            BEYOÄLU                       Yerli
# 16962        2018-11-25           BAKIRKÃY                       Yerli
# 16963        2019-09-25              KARTAL                       Yerli
# 16964        2018-05-20             MALTEPE                       Yerli
#
#        LONGITUDE   LATITUDE  NUMBER_OF_SUBSCRIBER
# 0      29.011473  41.080041                     1
# ...

# %%
#şimdii 1 milyon satır olmayan güzel verilerimize bakalım, amaa enlem boylam içerenlere çünkü enlem boylamsız tüm verileri birletşirdik.

import pandas as pd
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="rhjhgf")

def enlemboylam(filename,Latitude='Latitude',Longitude='Longitude'):
    for i in range(len(filename)):
        lon= filename.loc[i,Longitude]
        lat= filename.loc[i,Latitude]
        k='{},{}'.format(lat,lon)
        raws=geolocator.reverse(k).raw['address']
        try:
            filename.loc[i,'Mahalleler']=raws['neighbourhood']
        except:
            try:
                filename.loc[i,'Mahalleler']=raws['village']
            except:
                try:
                    filename.loc[i,'Mahalleler']=raws['city_district']
                except:
                    pass
        try:
            filename.loc[i,'COUNTY_NAME']=raws['county']
        except:
            try:
                filename.loc[i,'COUNTY_NAME']=raws['town']
            except:
                pass
        if (i%50)==0:
            print(i,k)
    return print('son')

# %%
enlemboylam(link25,Latitude='LATITUDE',Longitude='LONGITUDE')

# %%
dosyalar[27]
# Out:
#              İlçe       2015       2016       2017       2018       2019
# 0         KADIKÖY  289799975  334484790  381418733  407184428  382648400
# 1        ESENYURT  286305791  270714840  310456446  306478633  270391774
# 2          PENDİK  259782434  265760154  293350294  291409388  260462353
# 3    KÜÇÜKÇEKMECE  258612726  257019311  291513204  281520286  256603576
# 4        ÜMRANİYE  243420288  236508313  283845936  271213413  237214965
# 5         ÜSKÜDAR  228472669  228845546  254094119  239474552  210159134
# 6    BAHÇELİEVLER  208697683  209962616  225841484  225819835  200595190
# 7        BAĞCILAR  194262149  205157465  220599107  215813578  194966321
# 8         SARIYER  184647704  197803870  220129541  213166985  185898510
# 9        BAKIRKÖY  184401673  190011929  209936316  205345705  180569905
# 10        MALTEPE  176766357  188495814  201323285  191692282  171969204
# 11          ŞİŞLİ  167969376  182252261  194602820  191040594  159299768
# ...

# %%
k11=pd.merge(k10,dosyalar[27], left_on=["CountyName"] ,right_on=["İlçe"], how="left")

# %%
k11=k11.drop(columns=["İlçe"])

# %%
k11.columns
# Out:
# Index([                        'CountyName',
#                              'DistrictName',
#                       'afet_ibblocnamesayi',
#                         'afet_mezarliksayi',
#                             'Gelen Arıza_x',
#                           'Giderilen Arıza',
#             'cevre_kanalgelcagrisayisi_y19',
#             'cevre_kanalgidcagrisayisi_y19',
#                'cevre_sugelcagrisayisi_y19',
#                'cevre_sucevcagrisayisi_y19',
#                'cevre_suzlukgelcagrisayisi',
#                'cevre_suzlukgidcagrisayisi',
#                              'guvenlik_SES',
#                   'guvenlik_SES_SCORE-2016',
#                      'enerji_ilceabonesayi',
#          'guvenlik_bina_sayisi_1980_oncesi',
#        'guvenlik_bina_sayisi_19802000arasi',
#         'guvenlik_bina_sayisi_2000_sonrasi',
#            'guvenlik_binasayisi1_4katarasi',
#            'guvenlik_binasayisi5_9katarasi',
#           'guvenlik_binasayisi9_19katarasi',
# ...

# %%
k11=k11.rename(columns={2015: 'enerji_dogalgazharcm3_2015'})
k11=k11.rename(columns={2016: 'enerji_dogalgazharcm3_2016'})
k11=k11.rename(columns={2017: 'enerji_dogalgazharcm3_2017'})
k11=k11.rename(columns={2018: 'enerji_dogalgazharcm3_2018'})
k11=k11.rename(columns={2019: 'enerji_dogalgazharcm3_2019'})

# %%
k11
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
dosyalar[2]
# Out:
#           ID                                     NAME COUNTY_NAME  \
# 0    1186055         Caddebostan Mahallesi Muhtarlığı     KADIKÖY
# 1    1185765           Rami Cuma Mahallesi Muhtarlığı  EYÜPSULTAN
# 2    1185782           Karadolap Mahallesi Muhtarlığı  EYÜPSULTAN
# 3    1185861  Mustafa Kemal Paşa Mahallesi Muhtarlığı     AVCILAR
# 4    1183811          Zerzevatçı Mahallesi Muhtarlığı      BEYKOZ
# ..       ...                                      ...         ...
# 955  1184159     Hoca Gıyasettin Mahallesi Muhtarlığı       FATİH
# 956  1185575           Havaalanı Mahallesi Muhtarlığı     ESENLER
# 957  1186015             İmrahor Mahallesi Muhtarlığı  ARNAVUTKÖY
# 958  1185377             Erenköy Mahallesi Muhtarlığı     KADIKÖY
# 959  4750244          Sancaktepe Mahallesi Muhtarlığı     SİLİVRİ
#
#      NEIGHBORHOOD_NAME
# 0          CADDEBOSTAN
# 1            RAMİ CUMA
# 2            KARADOLAP
# 3    MUSTAFA KEMALPAŞA
# 4           ZERZAVATÇI
# ..                 ...
# ...

# %%
dosyalar[2]=dosyalar[2].groupby(['COUNTY_NAME','NEIGHBORHOOD_NAME'])['NAME'].count().reset_index()

# %%
k12=pd.merge(k11,dosyalar[2], left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","NEIGHBORHOOD_NAME"], how="left")

# %%
k12
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3           FATİH        YAVUZ SULTAN SELİM                  1.0
# 4         ÇATALCA                 OVAYENİCE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKİF                  NaN
# 968         ŞİŞLİ                İZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  Gelen Arıza_x  Giderilen Arıza  \
# 0                  NaN            NaN              NaN
# 1                  NaN        18261.0          18122.0
# ...

# %%
k12=k12.drop(columns=["COUNTY_NAME","NEIGHBORHOOD_NAME"])

# %%
k12=k12.rename(columns={"NAME": 'afet_muhtarliksayi'})

# %%
input1
# Out:
#       2020-08-11 11:00:00  28.7127685546875  40.9872436523438  sxk3jm   6  \
# 0     2020-08-09 19:00:00         29.371948         40.937805  sxkbuk  45
# 1     2020-08-25 10:00:00         28.888550         41.102600  sxk9c6   6
# 2     2020-08-06 20:00:00         29.075317         41.014709  sxk9md   6
# 3     2020-08-13 21:00:00         28.372192         41.163025  sxk4jt  58
# 4     2020-08-27 14:00:00         28.833618         40.965271  sxk901   7
# ...                   ...               ...               ...     ...  ..
# 9994  2020-08-05 01:00:00         29.426880         40.794983  sxkbjd  46
# 9995  2020-08-11 10:00:00         28.899536         41.102600  sxk9cd   6
# 9996  2020-08-11 20:00:00         28.602905         41.234436  sxk6df   7
# 9997  2020-08-04 15:00:00         28.690796         41.047668  sxk3sb   7
# 9998  2020-08-27 12:00:00         28.383179         41.053162  sxk1tc   7
#
#        78  32  252
# 0     186  99   47
# 1      73  27   87
# ...

# %%
DATE_TIME,TRANSPORT_TYPE_ID,TRANSPORT_TYPE_DESC,LINE,TRANSFER_TYPE_ID,TRANSFER_TYPE,NUMBER_OF_PASSENGER,NUMBER_OF_PASSAGE

# %%
input1=input1.rename(columns={"2020-08-11 11:00:00": 'DATE_TIME',"28.7127685546875":"TRANSPORT_TYPE_ID","40.9872436523438": "TRANSPORT_TYPE_DESC","sxk3jm":"LINE","6":"TRANSFER_TYPE_ID","78":"TRANSFER_TYPE","32":"NUMBER_OF_PASSENGER","252":"NUMBER_OF_PASSAGE"})

# %%
k12.columns
# Out:
# Index(['CountyName', 'DistrictName', 'afet_ibblocnamesayi',
#        'afet_mezarliksayi', 'cevre_gelcagrisayisi_y19',
#        'cevre_gidcagrisayisi_y19', 'cevre_kanalgelcagrisayisi_y19',
#        'cevre_kanalgidcagrisayisi_y19', 'cevre_sugelcagrisayisi_y19',
#        'cevre_sucevcagrisayisi_y19', 'cevre_suzlukgelcagrisayisi',
#        'cevre_suzlukgidcagrisayisi', 'guvenlik_SES', 'guvenlik_SES_SCORE-2016',
#        'enerji_ilceabonesayi', 'guvenlik_bina_sayisi_1980_oncesi',
#        'guvenlik_bina_sayisi_19802000arasi',
#        'guvenlik_bina_sayisi_2000_sonrasi', 'guvenlik_binasayisi1_4katarasi',
#        'guvenlik_binasayisi5_9katarasi', 'guvenlik_binasayisi9_19katarasi',
#        'insan_okumabilinmeyensayisi', 'insan_okumayazmabilensayisi',
#        'insan_okumayazmabilmeyensayisi', 'yonetisim_orthanebuyuklugu_2018',
#        'enerji_dogalgazharcm3_2015', 'enerji_dogalgazharcm3_2016',
#        'enerji_dogalgazharcm3_2017', 'enerji_dogalgazharcm3_2018',
# ...

# %%
k12=k12.rename(columns={"Gelen Arıza_x":"cevre_gelcagrisayisi_y19","Giderilen Arıza":"cevre_gidcagrisayisi_y19"})

# %%
#18.03.2021 enlem boylamı okuması uzun sürdüğü için efenin gönderdiği mahalle guncel utf verisetinden 110 civarı veriyi seçip onları da ekleme kararı aldım.

# %%
def display_all(link89.columns):     # for any Dataframe df
   with pd.option_context('display.max_rows',1000): # change number of rows accordingly
      with pd.option_context('display.max_columns',1000): # change number of columns accordingly
          display(link89)

# %%
k12.head()
# Out:
#      CountyName              DistrictName  afet_ibblocnamesayi  \
# 0  KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1       AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2      ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3         FATİH        YAVUZ SULTAN SELİM                  1.0
# 4       ÇATALCA                 OVAYENİCE                  NaN
#
#    afet_mezarliksayi  cevre_gelcagrisayisi_y19  cevre_gidcagrisayisi_y19  \
# 0                NaN                       NaN                       NaN
# 1                NaN                   18261.0                   18122.0
# 2                2.0                   44808.0                   44477.0
# 3                1.0                   52522.0                   52141.0
# 4                1.0                   16335.0                   16241.0
#
#    cevre_kanalgelcagrisayisi_y19  cevre_kanalgidcagrisayisi_y19  \
# 0                            NaN                            NaN
# ...

# %%
link89
# Out:
#            Id  CityName  CityId    CountyName  CountyId VillageName  \
# 2      289700  İSTANBUL      34  KÜÇÜKÇEKMECE      1823      MERKEZ
# 8      293378  İSTANBUL      34       AVCILAR      2003      MERKEZ
# 27     283974  İSTANBUL      34      ESENYURT      2053      MERKEZ
# 73     287208  İSTANBUL      34         FATİH      1327      MERKEZ
# 113    302491  İSTANBUL      34       ÇATALCA      1237      MERKEZ
# ...       ...       ...     ...           ...       ...         ...
# 30485  302358  İSTANBUL      34      ÜMRANİYE      1852      MERKEZ
# 30486  302482  İSTANBUL      34  BÜYÜKÇEKMECE      1782      MERKEZ
# 30516  297693  İSTANBUL      34  KÜÇÜKÇEKMECE      1823      MERKEZ
# 30578  302329  İSTANBUL      34         ŞİŞLİ      1663      MERKEZ
# 30591  293402  İSTANBUL      34      BAĞCILAR      2004      MERKEZ
#
#        VillageId  IsMunicipality  MunicipalityId         MunicipalityName  \
# 2          16674            True            2276  KÜÇÜKÇEKMECE BELEDİYESİ
# ...

# %%
link89=link89.drop(columns=["Id","CityName","CityId","CountyId","VillageName","VillageId","IsMunicipality","MunicipalityId","MunicipalityName",
                     "DistrictId","DistrictType","DataLevel","DataLevelDescription","TurkeyIndex","CityIndex","CountyIndex","SesGroupAPlus","SesGroupA","SesGroupB","SesGroupC","SesGroupD"])

# %%
link89=link89.drop(columns=["HouseIncome","HouseIncomeTotal", "EduUnknown","EduNonLiterated","EduLiteratedUntutored", "Total_BB_Sale_2010",
 "Total_BB_Sale_2011",
 "Total_BB_Sale_2012",
 "Total_BB_Sale_2013",
 "Total_BB_Sale_2014",
 "Total_BB_Sale_2015",
 "Total_BB_Sale_2016",
 "Total_BB_Sale_2017",
 "Total_BB_Sale_2018"])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
link89.columns
# Out:
# Index(['CountyName', 'DistrictName', 'HousingCount', 'SummerResortCount',
#        'CommercialCount', 'PopulationTotal', 'PopulationMale',
#        'PopulationFemale', 'HouseholdCount', 'MarriedNever',
#        ...
#        'OnlineRetailOnly', 'MultichannelVacationTravel',
#        'OnlineVacationOnlyTravel', 'MultichannelRetailElectronics',
#        'MultichannelRetailClothingShoes', 'MultichannelRetailHomeDecoration',
#        'MultichannelRetailEntertainmentCulture', 'OnlineRetailOnlyMarketplace',
#        'OnlineRetailOnlyVertical', 'MultichannelRetailOthers'],
#       dtype='object', length=129)

# %%
#bütün kolonları göstermek için
list(link89.columns)

# %%
k13=pd.merge(k12,link89, left_on=["CountyName","DistrictName"] ,right_on=["CountyName","DistrictName"], how="left")

# %%
k13.to_csv('k13.csv',index=False)

# %%
# Out:
# Index(['Id', 'CityName', 'CityId', 'CountyName', 'CountyId', 'VillageName',
#        'VillageId', 'IsMunicipality', 'MunicipalityId', 'MunicipalityName',
#        ...
#        'OnlineRetailOnly', 'MultichannelVacationTravel',
#        'OnlineVacationOnlyTravel', 'MultichannelRetailElectronics',
#        'MultichannelRetailClothingShoes', 'MultichannelRetailHomeDecoration',
#        'MultichannelRetailEntertainmentCulture', 'OnlineRetailOnlyMarketplace',
#        'OnlineRetailOnlyVertical', 'MultichannelRetailOthers'],
#       dtype='object', length=216)

# %%
k13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Columns: 158 entries, CountyName to MultichannelRetailOthers
# dtypes: float64(42), int64(113), object(3)
# memory usage: 1.2+ MB

# %%
k13["Amo"]

# %%
list(k13.columns)
# Out:
# ['CountyName',
#  'DistrictName',
#  'afet_ibblocnamesayi',
#  'afet_mezarliksayi',
#  'cevre_gelcagrisayisi_y19',
#  'cevre_gidcagrisayisi_y19',
#  'cevre_kanalgelcagrisayisi_y19',
#  'cevre_kanalgidcagrisayisi_y19',
#  'cevre_sugelcagrisayisi_y19',
#  'cevre_sucevcagrisayisi_y19',
#  'cevre_suzlukgelcagrisayisi',
#  'cevre_suzlukgidcagrisayisi',
#  'guvenlik_SES',
#  'guvenlik_SES_SCORE-2016',
#  'enerji_ilceabonesayi',
#  'guvenlik_bina_sayisi_1980_oncesi',
#  'guvenlik_bina_sayisi_19802000arasi',
#  'guvenlik_bina_sayisi_2000_sonrasi',
#  'guvenlik_binasayisi1_4katarasi',
#  'guvenlik_binasayisi5_9katarasi',
#  'guvenlik_binasayisi9_19katarasi',
#  'insan_okumabilinmeyensayisi',
#  'insan_okumayazmabilensayisi',
#  'insan_okumayazmabilmeyensayisi',
#  'yonetisim_orthanebuyuklugu_2018',
#  'enerji_dogalgazharcm3_2015',
#  'enerji_dogalgazharcm3_2016',
#  'enerji_dogalgazharcm3_2017',
#  'enerji_dogalgazharcm3_2018',
#  'enerji_dogalgazharcm3_2019',
#  'afet_muhtarliksayi',
# ...

# %%
mahalledeger = pd.read_csv("MahalleDeger4.csv",encoding= 'ISO-8859-9',engine='python')

# %%
mahalledeger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11285 entries, 0 to 11284
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PropertyMonth          11285 non-null  int64
#  1   PropertyYear           11285 non-null  int64
#  2   DisplayName            0 non-null      float64
#  3   UnitPriceForSale       10890 non-null  float64
#  4   MinUnitPriceForSale    10890 non-null  float64
#  5   MaxUnitPriceForSale    10890 non-null  float64
#  6   ComparableAreaForSale  10890 non-null  float64
#  7   CountForSale           10890 non-null  float64
#  8   UnitPriceForRent       7507 non-null   float64
#  9   MinUnitPriceForRent    7507 non-null   float64
#  10  MaxUnitPriceForRent    7507 non-null   float64
#  11  ComparableAreaForRent  7507 non-null   float64
#  12  CountForRent           7507 non-null   float64
#  13  AnalysisType           11285 non-null  int64
# ...

# %%
k14=pd.merge(k13,mahalledeger, left_on=["CountyName","DistrictName"] ,right_on=["CountyName","DistrictName"], how="left")

# %%
list(k14.columns)
# Out:
# ['CountyName',
#  'DistrictName',
#  'afet_ibblocnamesayi',
#  'afet_mezarliksayi',
#  'cevre_gelcagrisayisi_y19',
#  'cevre_gidcagrisayisi_y19',
#  'cevre_kanalgelcagrisayisi_y19',
#  'cevre_kanalgidcagrisayisi_y19',
#  'cevre_sugelcagrisayisi_y19',
#  'cevre_sucevcagrisayisi_y19',
#  'cevre_suzlukgelcagrisayisi',
#  'cevre_suzlukgidcagrisayisi',
#  'guvenlik_SES',
#  'guvenlik_SES_SCORE-2016',
#  'enerji_ilceabonesayi',
#  'guvenlik_bina_sayisi_1980_oncesi',
#  'guvenlik_bina_sayisi_19802000arasi',
#  'guvenlik_bina_sayisi_2000_sonrasi',
#  'guvenlik_binasayisi1_4katarasi',
#  'guvenlik_binasayisi5_9katarasi',
#  'guvenlik_binasayisi9_19katarasi',
#  'insan_okumabilinmeyensayisi',
#  'insan_okumayazmabilensayisi',
#  'insan_okumayazmabilmeyensayisi',
#  'yonetisim_orthanebuyuklugu_2018',
#  'enerji_dogalgazharcm3_2015',
#  'enerji_dogalgazharcm3_2016',
#  'enerji_dogalgazharcm3_2017',
#  'enerji_dogalgazharcm3_2018',
#  'enerji_dogalgazharcm3_2019',
#  'afet_muhtarliksayi',
# ...

# %%
k14=k14.drop(columns=["CityId","CountyId","DistrictId"])

# %%
k14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Columns: 195 entries, CountyName to PropertyCount
# dtypes: float64(77), int64(113), object(5)
# memory usage: 1.5+ MB

# %%
k14.to_csv("k14.csv",index=False)

# %%
k14["afet_ibb"]

# %%
airbnb["neighbourhood"]=airbnb["neighbourhood"].str.replace('i','İ').str.upper()

# %%
airbnb=pd.read_csv('AirbnbIstanbul.csv')

# %%
k14.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cbe3092af491> in <module>
# ----> 1 k14.head()
#
# NameError: name 'k14' is not defined

# %%
k15=pd.merge(k14,airbnb, left_on=["CountyName"] ,right_on=["neighbourhood"], how="left")

# %%
k15.head()
# Out:
#      CountyName              DistrictName  afet_ibblocnamesayi  \
# 0  KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB                  NaN
# 1       AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2      ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 3      ESENYURT         SELAHADDİN EYYUBİ                  NaN
# 4      ESENYURT         SELAHADDİN EYYUBİ                  NaN
#
#    afet_mezarliksayi  cevre_gelcagrisayisi_y19  cevre_gidcagrisayisi_y19  \
# 0                NaN                       NaN                       NaN
# 1                NaN                   18261.0                   18122.0
# 2                2.0                   44808.0                   44477.0
# 3                2.0                   44808.0                   44477.0
# 4                2.0                   44808.0                   44477.0
#
#    cevre_kanalgelcagrisayisi_y19  cevre_kanalgidcagrisayisi_y19  \
# 0                            NaN                            NaN
# ...

# %%
k15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Columns: 211 entries, CountyName to availability_365
# dtypes: float64(88), int64(113), object(10)
# memory usage: 1.6+ MB

# %%
k15.shape
# Out:
# (160826, 211)

# %%
k15.to_csv("k15.csv",index=False)

# %% [markdown]
# DATA ANALYSIS
# with Seca

# %%
dosyalar[8]["Mahalleler"]=dosyalar[8]["Mahalleler"].str.replace('Mahallesi','')
dosyalar[8]["Mahalleler"]=dosyalar[8]["Mahalleler"].str.strip()
dosyalar[8]["Mahalleler"]=dosyalar[8]["Mahalleler"].str.replace('i','İ').str.upper()

# %%
dosyalar8=dosyalar[8].rename(columns={'Gelen Çağrı Sayısı': 'cevre_suzlukgelcagrisayisi'})
dosyalar8=dosyalar[8].rename(columns={'Cevaplanan Çağrı Sayısı': 'cevre_suzlukgidcagrisayisi'})

# %%
k6=pd.merge(k5,dosyalar8, left_on=["CountyName","DistrictName"] ,right_on=["İlçe","Mahalleler"], how="left")

# %%
k6
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE IKITELLIOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDIN EYYUBI                  NaN
# 3           FATİH        YAVUZ SULTAN SELIM                  1.0
# 4         ÇATALCA                 OVAYENICE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKIF                  NaN
# 968         ŞİŞLİ                IZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  afet_muhtarliksayi  cevre_gelcagrisayisi_y19  \
# 0                  NaN                 NaN                   41302.0
# ...

# %%
k6=k6.rename(columns={'Gelen Çağrı Sayısı': 'cevre_suzlukgelcagrisayisi'})
k6=k6.drop(columns=["İlçe","Mahalleler"])

# %%
k6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 969
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CountyName                     970 non-null    object
#  1   DistrictName                   970 non-null    object
#  2   afet_ibblocnamesayi            361 non-null    float64
#  3   afet_mezarliksayi              244 non-null    float64
#  4   afet_muhtarliksayi             571 non-null    float64
#  5   cevre_gelcagrisayisi_y19       816 non-null    float64
#  6   cevre_gidcagrisayisi_y19       816 non-null    float64
#  7   cevre_kanalgelcagrisayisi_y19  392 non-null    float64
#  8   cevre_kanalgidcagrisayisi_y19  392 non-null    float64
#  9   cevre_sugelcagrisayisi_y19     266 non-null    float64
#  10  cevre_sugelcagrisayisi_y19     266 non-null    float64
#  11  cevre_suzlukgelcagrisayisi     5 non-null      float64
# ...

# %%
dosyalar[8]["Mahalleler"]=dosyalar[8]["Mahalleler"].str.replace('İ','I').str.upper()

# %%
k6.to_csv("k6.csv")

# %%
k6.
# Out:
#        CountyName              DistrictName  afet_ibblocnamesayi  \
# 0    KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE IKITELLIOSB                  NaN
# 1         AVCILAR         MUSTAFA KEMALPAŞA                  NaN
# 2        ESENYURT         SELAHADDIN EYYUBI                  NaN
# 3           FATİH        YAVUZ SULTAN SELIM                  1.0
# 4         ÇATALCA                 OVAYENICE                  NaN
# ..            ...                       ...                  ...
# 965      ÜMRANİYE             AŞAĞI DUDULLU                  NaN
# 966  BÜYÜKÇEKMECE                   TÜRKOBA                  1.0
# 967  KÜÇÜKÇEKMECE               MEHMET AKIF                  NaN
# 968         ŞİŞLİ                IZZET PAŞA                  NaN
# 969      BAĞCILAR                 KEMALPAŞA                  NaN
#
#      afet_mezarliksayi  afet_muhtarliksayi  cevre_gelcagrisayisi_y19  \
# 0                  NaN                 NaN                   41302.0
# ...

# %%
dosyalar[6]
# Out:
#       Yıl    İlçe                 Mahalleler  Gelen Arıza  Cevaplanan Arıza
# 0    2019  ADALAR  ADALAR-STANDARTDİŞİ ADRES            1               NaN
# 1    2019  ADALAR               BURGAZ ADASİ           95              95.0
# 2    2019  ADALAR                HEYBELİ ADA          109             109.0
# 3    2019  ADALAR                 KİNALİ ADA          108             108.0
# 4    2019  ADALAR       MADEN MAH.- BÜYÜKADA          168             166.0
# ..    ...     ...                        ...          ...               ...
# 993  2019   ŞİŞLİ                   PAŞA MAH          264             264.0
# 994  2019   ŞİŞLİ              TEŞVİKİYE MAH          344             344.0
# 995  2019   ŞİŞLİ                  YAYLA MAH          190             190.0
# 996  2019   ŞİŞLİ                  İNÖNÜ MAH          129             129.0
# 997  2019   ŞİŞLİ             İZZET PAŞA MAH          197             197.0
#
# [998 rows x 5 columns]

# %%
link25
# Out:
#                              NAME  LONGITUDE   LATITUDE NEIGHBORHOOD_NAME  \
# 0              Yayla Sokak ParkÄ±  28.925082  41.081198       AKŞEMSETTİN
# 1                     Stad ParkÄ±  28.914355  40.994647            TELSİZ
# 2             Kadriye GÃ¶k ParkÄ±  28.899872  40.990061          NURİPAŞA
# 3                    Tutya ParkÄ±  28.937360  41.009753       SEYYİD ÖMER
# 4             Ãukurbostan ParkÄ±  28.933638  41.011341         ŞEHREMİNİ
# ...                           ...        ...        ...               ...
# 3621           1415. Sok . ParkÄ±  28.895567  41.104201              GAZİ
# 3622     Yedikule SurlarÄ± ParkÄ±  28.922778  40.993955          YEDİKULE
# 3623  BaÄlarbaÅÄ± Ãocuk ParkÄ±  29.035293  41.024379        SELAMİ ALİ
# 3624                         Park  29.027359  41.085210              AKAT
# 3625                         Park  28.827317  41.007614        ÇOBANÇEŞME
#
#        COUNTY_NAME
# 0             EYÜP
# 1      ZEYTİNBURNU
# ...

# %%
#çalıştırma
def enlemboylam(filename):
    for i in range(len(filename)):
        lon= filename.loc[i,'LONGITUDE']
        lat= filename.loc[i,'LATITUDE']
        k='{},{}'.format(lat,lon)
        raws=geolocator.reverse(k).raw['address']
        try:
            filename.loc[i,'Mahalleler']=raws['neighbourhood']
        except:
            try:
                filename.loc[i,'Mahalleler']=raws['village']
            except:
                try:
                    filename.loc[i,'Mahalleler']=raws['city_district']
                except:
                    pass
        try:
            filename.loc[i,'COUNTY_NAME']=raws['county']
        except:
            try:
                filename.loc[i,'COUNTY_NAME']=raws['town']
            except:
                pass
        if (i%50)==0:
            print(i,k)
    return print('son')

# %%
#çalıştırma
#enlemboylam(dosyalar[0])

# %%
onums =[]

for i in range(len(dosyalar[0])):
    lon= dosyalar[0].loc[i,'LONGITUDE']
    lat= dosyalar[0].loc[i,'LATITUDE']
    k='{},{}'.format(lat,lon)
    raw=
    try:
        dosyalar[0].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['city_district']
    except:
        try:
            dosyalar[0].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['village']
        except:
            pass
    try:
        dosyalar[0].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['county']
    except:
        try:
            dosyalar[0].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['town']
        except:
            pass
    print(i, k)

# %%
#çalıştırma
lon= dosyalar[0].loc[4,'LONGITUDE']
lat= dosyalar[0].loc[4,'LATITUDE']
k='{},{}'.format(lat,lon)
raw=geolocator.reverse(k).raw['address']
print(raw["neighbourhood"])

# %%
konums =[]

for i in range(len(dosyalar[8])):
    lon= dosyalar[8].loc[i,'Enlem']
    lat= dosyalar[8].loc[i,'Boylam']
    k='{},{}'.format(lat,lon)
print(k)

# %%
dosyalar[9].add.column["Mahalle"]

# %%
#dosyalar[9]['mahalle'] = None

# %%
#dosyalar[9]

# %%
konums =[]

for i in range(len(dosyalar[32])):
    lon= dosyalar[32].loc[i,'Longitude']
    lat= dosyalar[32].loc[i,'Latitude']
    k='{},{}'.format(lat,lon)
    try:
        
        dosyalar[32].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['city_district']
    except:
        dosyalar[32].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['village']
        pass
    try:
        dosyalar[32].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['county']
    except:
        dosyalar[32].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['town']
        pass
    print(i, k)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="rrdfsdf")
location = geolocator.reverse(" 38.98, 27.86")

# %%
location.raw

# %%
dosyalar[32]

# %%
for i in range(len(dosyalar[31])):
    lon= dosyalar[31].loc[i,'Longitude']
    lat= dosyalar[31].loc[i,'Latitude']
    k='{},{}'.format(lat,lon)
    try:
        
        dosyalar[31].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['city_district']
    except:
        dosyalar[31].loc[i,'Mahalleler']=geolocator.reverse(k).raw['address']['village']
        pass
    try:
        dosyalar[31].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['county']
    except:
        dosyalar[31].loc[i,'COUNTY_NAME']= geolocator.reverse(k).raw['address']['town']
        pass
    print(i, k)

# %%
dosyalar[37]

# %%
#enlem boylam degisimi gerekenler: link1, link32, link38, link41, link55,

# %%
link33 = pd.read_excel("guvenlik-itfaiye-konum-verisi.xlsx",encoding= 'ISO-8859-9',sheet_name='istasyonlar')

# %%
link33

# %%
link33 = pd.read_excel("guvenlik-itfaiye-konum-verisi2.xlsx",sheet_name='istasyonlar')

link33[['Latitude','Longitude']] = link33.Koordinat.str.split(",",expand=True,)

# %%
dosyalar2
# Out:
#                     Mahalleler   COUNTY_NAME  LOCATION_NAME
# 0                    100. YIL       BAĞCILAR              1
# 1                    19 MAYIS          ŞIŞLI              5
# 2                     50. YIL     SULTANGAZI              1
# 3                     75. YIL     SULTANGAZI              2
# 4    ABDURRAHMAN NAFIZ GÜRMAN       GÜNGÖREN              3
# ..                         ...           ...            ...
# 387                 ŞEHREMINI          FATIH              2
# 388                    ŞENLIK       BAKIRKÖY              3
# 389                    ŞENYUVA   ÇAMLIHEMŞIN              1
# 390                  ŞERIFALI       ÜMRANIYE              1
# 391                ŞIRINEVLER   BAHÇELIEVLER              3
#
# [392 rows x 3 columns]

# %%
link1
# Out:
# 907

# %%
k=pd.merge(link90,link2, left_on=["CountyName","DistrictName"] ,right_on=["COUNTY_NAME","NEIGHBORHOOD_NAME"], how="left")

# %%
k
# Out:
#         CountyName              DistrictName            ID  \
# 0     KÜÇÜKÇEKMECE  KÜÇÜKÇEKMECE İKİTELLİOSB           NaN
# 1          AVCILAR         MUSTAFA KEMALPAŞA           NaN
# 2         ESENYURT         SELAHADDİN EYYUBİ  4.110002e+06
# 3         ESENYURT         SELAHADDİN EYYUBİ  1.500000e+09
# 4            FATİH        YAVUZ SULTAN SELİM  4.200013e+06
# ...            ...                       ...           ...
# 1113      ÜMRANİYE             AŞAĞI DUDULLU           NaN
# 1114  BÜYÜKÇEKMECE                   TÜRKOBA  1.500000e+09
# 1115  KÜÇÜKÇEKMECE               MEHMET AKİF           NaN
# 1116         ŞİŞLİ                İZZET PAŞA           NaN
# 1117      BAĞCILAR                 KEMALPAŞA           NaN
#
#                          NAME   COUNTY_NAME   NEIGHBORHOOD_NAME
# 0                         NaN           NaN                 NaN
# 1                         NaN           NaN                 NaN
# ...

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1118 entries, 0 to 1117
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CountyName         1118 non-null   object
#  1   DistrictName       1118 non-null   object
#  2   ID                 392 non-null    float64
#  3   NAME               392 non-null    object
#  4   COUNTY_NAME        392 non-null    object
#  5   NEIGHBORHOOD_NAME  392 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 61.1+ KB

# %%
dosyalar3=dosyalar[1].groupby(['Mahalleler','COUNTY_NAME'])['NAME'].count().reset_index()

# %%
link1
# Out:
#              ID                                        NAME  COUNTY_NAME  \
# 0       1133899                    Kadıköy Musevi Mezarlığı      KADİKÖY
# 1    1500000039                         Ovayenice Mezarlığı      ÇATALCA
# 2     113001361                         Dursunköy Mezarlığı   ARNAVUTKÖY
# 3    1500000103                    Yukarı Baklacı Mezarlığı       BEYKOZ
# 4       1133902                           Ayvalık Mezarlığı  ZEYTİNBURNU
# ..          ...                                         ...          ...
# 609     1133901  Silivrikapı Balıklı Rum Ortadoks Mezarlığı  ZEYTİNBURNU
# 610  1500000080                         Necatibey Mezarlığı         EYÜP
# 611  1500000085                     Yukarı Ağaçlı Mezarlığı         EYÜP
# 612     1133497                       Silivrikapı Mezarlığı  ZEYTİNBURNU
# 613     1133490                         Şişli Rum Mezarlığı        ŞİŞLİ
#
#     NEIGHBORHOOD_NAME
# 0           HASANPAŞA
# 1           OVAYENİCE
# ...

# %%
dosyalar3
# Out:
#           Mahalleler   COUNTY_NAME  NAME
# 0             19.MAY  BÜYÜKÇEKMECE     1
# 1    ABDURRAHMANGAZİ   SULTANBEYLİ     2
# 2         ADEM YAVUZ      ÜMRANİYE     1
# 3      ADNAN KAHVECİ    BEYLİKDÜZÜ     1
# 4           AHMEDİYE  BÜYÜKÇEKMECE     1
# ..               ...           ...   ...
# 384        İÇERENKÖY      ATAŞEHİR     1
# 385          İŞİKLAR          EYÜP     1
# 386           ŞAMLAR    BAŞAKŞEHİR     1
# 387           ŞEYHLİ        PENDİK     2
# 388         ŞUAYİPLİ          ŞİLE     7
#
# [389 rows x 3 columns]

# %%
def enlemboylam(filename,Latitude='Latitude',Longitude='Longitude'):
    for i in range(len(filename)):
        lon= filename.loc[i,Longitude]
        lat= filename.loc[i,Latitude]
        k='{},{}'.format(lat,lon)
        raws=geolocator.reverse(k).raw['address']
        try:
            filename.loc[i,'Mahalleler']=raws['neighbourhood']
        except:
            try:
                filename.loc[i,'Mahalleler']=raws['village']
            except:
                try:
                    filename.loc[i,'Mahalleler']=raws['city_district']
                except:
                    pass
        try:
            filename.loc[i,'COUNTY_NAME']=raws['county']
        except:
            try:
                filename.loc[i,'COUNTY_NAME']=raws['town']
            except:
                pass
        if (i%50)==0:
            print(i,k)
    return print('son')

# %%
enlemboylam(link25,Latitude='LATITUDE',Longitude='LONGITUDE')
#link25 enlem boylam için
# Out:
# 0 41.081197707156896,28.925081594897698
# 50 41.0152800824715,29.1651748993541
# 100 41.072514767428004,28.884733451332398
# 150 41.02811684927279,28.9398373855138
# 200 41.0415824714774,29.0065848499062
# 250 40.971145854720795,29.2314847006118
# 300 41.0102362669898,29.078203928951602
# 350 41.023492715500204,29.1786704437018
# 400 40.9963260332734,29.152020971276603
# 450 40.9951376764819,28.834366335646898
# 500 40.903571927596005,29.1936956913724
# 550 41.0061731166323,29.085237033673
# 600 41.1756629313183,29.269280835520302
# 650 40.9922994855978,28.6197792144291
# 700 41.0421738672292,28.884411505275803
# 750 41.0070329507021,29.0964959268588
# 800 41.008165913169705,28.8194408611932
# 850 40.9801879944323,29.028486931616698
# 900 41.062069349927796,29.0267090607065
# 950 41.0681499187959,28.971398371697102
# 1000 41.0117113192038,28.9529494971095
# 1050 41.1744649622175,29.609422032370897
# 1100 40.9779793758198,28.8591131417455
# 1150 41.082168747291,29.0145409354913
# ...

# %%
link25.to_csv('link25.csv',index=False)

# %%
link25
# Out:
#                              NAME  LONGITUDE   LATITUDE NEIGHBORHOOD_NAME  \
# 0              Yayla Sokak ParkÄ±  28.925082  41.081198       AKŞEMSETTİN
# 1                     Stad ParkÄ±  28.914355  40.994647            TELSİZ
# 2             Kadriye GÃ¶k ParkÄ±  28.899872  40.990061          NURİPAŞA
# 3                    Tutya ParkÄ±  28.937360  41.009753       SEYYİD ÖMER
# 4             Ãukurbostan ParkÄ±  28.933638  41.011341         ŞEHREMİNİ
# ...                           ...        ...        ...               ...
# 3621           1415. Sok . ParkÄ±  28.895567  41.104201              GAZİ
# 3622     Yedikule SurlarÄ± ParkÄ±  28.922778  40.993955          YEDİKULE
# 3623  BaÄlarbaÅÄ± Ãocuk ParkÄ±  29.035293  41.024379        SELAMİ ALİ
# 3624                         Park  29.027359  41.085210              AKAT
# 3625                         Park  28.827317  41.007614        ÇOBANÇEŞME
#
#        COUNTY_NAME               Mahalleler
# ...

# %%
link38
# Out:
#       SUBSCRIPTION_DATE SUBSCRIPTION_COUNTY SUBSCRIBER_DOMESTIC_FOREIGN  \
# 0            2019-06-01       BAÅAKÅEHÄ°R                       Yerli
# 1            2018-03-19             MALTEPE                    YabancÄ±
# 2            2017-12-19          ÃEKMEKÃY                       Yerli
# 3            2017-12-30           BAKIRKÃY                       Yerli
# 4            2015-12-26          KAÄITHANE                       Yerli
# ...                 ...                 ...                         ...
# 16960        2018-07-03          SANCAKTEPE                       Yerli
# 16961        2017-12-17            BEYOÄLU                       Yerli
# 16962        2018-11-25           BAKIRKÃY                       Yerli
# 16963        2019-09-25              KARTAL                       Yerli
# 16964        2018-05-20             MALTEPE                       Yerli
#
#        LONGITUDE   LATITUDE  NUMBER_OF_SUBSCRIBER
# 0      29.011473  41.080041                     1
# ...

# %%
enlemboylam(link38,Latitude='LATITUDE',Longitude='LONGITUDE')
# Out:
# 0 41.080040999999994,29.011473
# 50 40.892454,29.189967
# 100 40.978551,28.820556
# 150 41.017041,29.105734
# 200 40.905838,29.161455
# 250 41.017758,28.941171
# 300 41.047359,28.933511
# 350 41.077425,29.338858000000002
# 400 41.014179999999996,28.582720000000002
# 450 41.017041,29.105734
# 500 40.978551,28.820556
# 550 41.017041,29.105734
# 600 40.995034000000004,28.705534999999998
# 650 40.978484,29.233057000000002
# 700 41.004253000000006,28.922037
# 750 40.892454,29.189967
# 800 41.04725,28.94027
# 850 40.995034000000004,28.705534999999998
# 900 40.924531,29.121198
# 950 41.04725,28.94027
# 1000 41.041218,29.00736
# 1050 41.044715000000004,28.796871999999997
# 1100 41.007712,28.972482
# 1150 40.888024,29.187151
# 1200 41.047359,28.933511
# 1250 41.015681,29.245334999999997
# 1300 41.080995,28.921595
# 1350 41.082908,28.948921999999996
# 1400 41.017041,29.105734
# 1450 41.047359,28.933511
# 1500 40.924531,29.121198
# 1550 41.030465,28.80303
# 1600 40.924531,29.121198
# ...

# %%
link38.to_csv('link38.csv',index=False)

# %%
link38=pd.read_csv("link38.csv")

# %%
link38
# Out:
#       SUBSCRIPTION_DATE SUBSCRIPTION_COUNTY SUBSCRIBER_DOMESTIC_FOREIGN  \
# 0            2019-06-01       BAÅAKÅEHÄ°R                       Yerli
# 1            2018-03-19             MALTEPE                    YabancÄ±
# 2            2017-12-19          ÃEKMEKÃY                       Yerli
# 3            2017-12-30           BAKIRKÃY                       Yerli
# 4            2015-12-26          KAÄITHANE                       Yerli
# ...                 ...                 ...                         ...
# 16960        2018-07-03          SANCAKTEPE                       Yerli
# 16961        2017-12-17            BEYOÄLU                       Yerli
# 16962        2018-11-25           BAKIRKÃY                       Yerli
# 16963        2019-09-25              KARTAL                       Yerli
# 16964        2018-05-20             MALTEPE                       Yerli
#
#        LONGITUDE   LATITUDE  NUMBER_OF_SUBSCRIBER             Mahalleler  \
# ...

# %%
link55
# Out:
#      Park ID                                Park Adı  Lokasyon ID  \
# 0        359                       Atatürk Bulvarı 1          150
# 1        860             Bakırköy İstanbul Caddesi 1          384
# 2        861             Bakırköy İstanbul Caddesi 2          384
# 3        862             Bakırköy İstanbul Caddesi 3          384
# 4        867             Bakırköy İstanbul Caddesi 8          384
# ..       ...                                     ...          ...
# 726     2831  Pendik Yenişehir Mustafa Akyol Sokak 1         2054
# 727     2832  Pendik Yenişehir Mustafa Akyol Sokak 2         2054
# 728     2885           Azapkapı Haliç Metro Otoparkı         2062
# 729     2837           Azapkapı Haliç Metro Otoparkı         2062
# 730     2842               Mecidiyeköy Açık Otoparkı         2065
#
#      Lokasyon Kodu                               Lokasyon Adı  Park Tipi ID  \
# 0                1                     0001 Atatürk Bulvarı 1             2
# ...

# %%
enlemboylam(link55,Latitude='Enlem',Longitude='Boylam')
# Out:
# 0 41.0112914996693,28.9535382991555
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/jupyterhub/lib/python3.6/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     342         try:
# --> 343             lat, lon = self._coerce_point_to_string(query).split(',')
#     344         except ValueError:
#
# /opt/jupyterhub/lib/python3.6/site-packages/geopy/geocoders/base.py in _coerce_point_to_string(self, point, output_format)
#     294         if not isinstance(point, Point):
# --> 295             point = Point(point)
#     296
#
# /opt/jupyterhub/lib/python3.6/site-packages/geopy/point.py in __new__(cls, latitude, longitude, altitude)
#     165             elif isinstance(arg, str):
# --> 166                 return cls.from_string(arg)
#     167             else:
#
# ...

# %%
link74
# Out:
#                    DATE_TIME  LONGITUDE   LATITUDE GEOHASH  MINIMUM_SPEED  \
# 0        2020-07-30 10:00:00  28.152466  41.135559  sxk408             64
# 1        2020-07-17 08:00:00  29.163208  40.981750  sxk9ps              6
# 2        2020-07-19 18:00:00  29.042358  41.119080  sxk9uv              6
# 3        2020-07-28 18:00:00  28.965454  41.080627  sxk9en              6
# 4        2020-07-12 02:00:00  29.218140  41.020203  sxkc2g             53
# ...                      ...        ...        ...     ...            ...
# 1390511  2020-07-26 09:00:00  29.218140  40.915833  sxkbbb             21
# 1390512  2020-07-27 21:00:00  28.789673  41.245422  sxk6xh             13
# 1390513  2020-07-11 12:00:00  28.712769  40.992737  sxk3jq              6
# 1390514  2020-07-07 16:00:00  29.251099  41.168518  sxkf1w             33
# 1390515  2020-07-01 11:00:00  28.668823  41.272888  sxk6u3             35
#
#          MAXIMUM_SPEED  AVERAGE_SPEED  NUMBER_OF_VEHICLES
# ...

# %%
enlemboylam(link74,Latitude='LATITUDE',Longitude='LONGITUDE')
# Out:
# 0 41.1355590820312,28.1524658203125
# 50 41.0256958007812,28.9544677734375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-641-bda6ccaf0876> in <module>
# ----> 1 enlemboylam(link74,Latitude='LATITUDE',Longitude='LONGITUDE')
#
# <ipython-input-630-359b80dbbf15> in enlemboylam(filename, Latitude, Longitude)
#       4         lat= filename.loc[i,Latitude]
#       5         k='{},{}'.format(lat,lon)
# ----> 6         raws=geolocator.reverse(k).raw['address']
#       7         try:
#       8             filename.loc[i,'Mahalleler']=raws['neighbourhood']
#
# /opt/jupyterhub/lib/python3.6/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     360         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     361         callback = partial(self._parse_json, exactly_one=exactly_one)
# ...
